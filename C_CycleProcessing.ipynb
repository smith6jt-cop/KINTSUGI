# %% [markdown]
# # KINTSUGI

# %% [markdown]
# ## In the following notebook you will use the parameters found in A_Evaluation&Testing.ipynb to correct and stitch entire datasets.

# %% [markdown]
# ### 1. Import packages. *This must be done every time the notebook is started or restarted.¶

# %% [markdown]
# Import these packages. Run cells using Ctrl+Enter.

# %%
from concurrent.futures import ProcessPoolExecutor
from concurrent.futures import ThreadPoolExecutor
import gc
import os as os
from tqdm import trange
import cupy as cp
import tkinter as tk
from tkinter import filedialog
from tkinter import simpledialog
import pandas as pd
from m2stitch import stitch_images
from basicpy import BaSiC, metrics
from glob import glob
from skimage.io.collection import alphanumeric_key
import shutil
from hyperactive import Hyperactive
import numpy as np
from skimage.io import imread 
from skimage.io import imsave
from skimage import io
from skimage import util
from skimage import exposure
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt
import jax
import pickle
from itertools import chain, repeat
import subprocess
from datetime import datetime
import imagej, scyjava
import logging
current_dateTime = datetime.now()

jax.config.update('jax_platform_name', 'cpu')

# %% [markdown]
# ### 2. Define directory paths. *This must be done every time the notebook is started or restarted.

# %% [markdown]
# Below are three ways to get the required paths to input, output, and meta folders.  The first is where they can be entered manually.  The second-fourth simply asks for the location of each.  The third reads from the project_data.txt file created in the first notebook and appends the variables to the global variable list.
#
# In each of these methods, a text file to store correction parameters is defined.
#
# Choose only one method: A, B, or C.

# %% [markdown]
# ### 2.1 Method A

# %%
base_dir = "C:/Users/smith6jt/KINTSUGI"
image_dir ="C:/Users/smith6jt/KINTSUGI/data/1904_CC2B28_raw"
stitch_dir = "C:/Users/smith6jt/KINTSUGI/data/1904_CC2B28_BaSiC_Stitched"
meta_dir = "C:/Users/smith6jt/KINTSUGI/data/1904_CC2B28_meta"
project_file = os.path.join(meta_dir, "project_data.txt")
print(f"Image folder is {image_dir}.")
print(f"Stitching folder is {stitch_dir}.")
print(f"Meta folder is {meta_dir}.")
# Out:
# Image folder is C:/Users/smith6jt/KINTSUGI/data/1904_CC2B28_raw.
# Stitching folder is C:/Users/smith6jt/KINTSUGI/data/1904_CC2B28_BaSiC_Stitched.
# Meta folder is C:/Users/smith6jt/KINTSUGI/data/1904_CC2B28_meta.

# %% [markdown]
# ### 2.2 Method B

# %%
# Enter image input directory.
image_dir = filedialog.askdirectory()
print(f"Image folder is {image_dir}.")

# %%
# Enter stitching output directory.
stitch_dir = filedialog.askdirectory()
project_file = os.path.join(meta_dir, "project_data.txt")
print(f"Stitching folder is {stitch_dir}.")

# %%
# Enter the metadata directory.
stitch_dir = filedialog.askdirectory()
project_file = os.path.join(meta_dir, "project_data.txt")
print(f"Meta folder is {meta_dir}.")

# %% [markdown]
# ### 2.3 Method C

# %% [markdown]
# If folder names were saved previously, import them here.

# %%
# Enter the metadata directory.
meta_dir = filedialog.askdirectory()
project_filename = os.path.join(meta_dir, "project_data.txt")
with open(project_file, 'r') as file:
        for line in file:
            try:
                line = line.strip()
                var_name, var_value = line.split('=')
                if var_name in globals():
                    print(f"{var_name} is {var_value}")
            except (ValueError):
                pass

# %% [markdown]
# ### 3. Stitching and Illumination Correction Functions

# %% [markdown]
# ### 3.1 Stitching Function

# %% [markdown]
# The following cell defines the function that is called from the apply_basic function to stitch the corrected tiles.  It creates the model from the middle z-plane images of the first channel, and then applies the model to the rest of the images for all channels in the cycle.

# %%
def stitch(images_transformed, zplanes, dest, dest_1, channels, zplanes_n, pou, rows, cols, overlap_percentage):
    
    z = str(zplanes)
    ch = str(channels)
    pkl_dest = os.path.join(dest, "result_df.pkl")
    
    if zplanes == zplanes_n//2 and channels == 1:
        # print(f"Start Stitching Z0{z.zfill(2)}_CH{ch}")
        if os.path.exists(pkl_dest):
            result_df = pd.read_pickle(pkl_dest)
        else:
            result_df, _ = stitch_images(images_transformed, rows, cols, initial_ncc_threshold=0.0, overlap_percentage=overlap_percentage, pou=pou, max_cores=10)
            result_df.to_pickle(pkl_dest)
            cp._default_memory_pool.free_all_blocks()
        
    else:
        # print(f"Start Stitching Z0{z.zfill(2)}_CH{ch}")
        if os.path.exists(os.path.join(dest_1, "result_df.pkl")):
            result_df = pd.read_pickle(os.path.join(dest_1, "result_df.pkl"))

        else:
            print("Run registration channel to produce a stitching model.")

    result_df["y_pos2"] = result_df["y_pos"] - result_df["y_pos"].min()
    result_df["x_pos2"] = result_df["x_pos"] - result_df["x_pos"].min()
    
    size_y = images_transformed.shape[1]
    size_x = images_transformed.shape[2]
    
    stitched_image_size = (
        result_df["y_pos2"].max() + size_y,
        result_df["x_pos2"].max() + size_x,
    )
    stitched_image = np.zeros_like(images_transformed, shape=stitched_image_size)
    
    for i, row in result_df.iterrows():
        stitched_image[
            row["y_pos2"] : row["y_pos2"] + size_y,
            row["x_pos2"] : row["x_pos2"] + size_x,
        ] = images_transformed[i]

    result_image_file_path = os.path.join(dest,f"{z.zfill(2)}.tif") 
    imsave(result_image_file_path, stitched_image, check_contrast=False)
    
    # print(f"Saved to {result_image_file_path}")

# %% [markdown]
# ### 3.2 Illumination Correction Function

# %% [markdown]
# The following cell contains the function that will apply the BaSiC correction to your data.  Make sure the number of leading zero digits in your cycle folder names is correct for 'zeros' and the filename pattern is correct for 'im_raw'.  This function runs BaSiC for the middle z-plane images and then reuses the correction model for the rest of the channel's images.  It then calls the stitching function.

# %%
def apply_basic(image_dir, stitch_dir, zplanes, cycles, channels, zplanes_n, pou, rows, cols, overlap_percentage):
    try:
        gc.collect()
        jax.clear_caches()    
        max_basic_workers = os.cpu_count()//2
        zeros = 3
        quant = 0.98
        filename_pattern = f'1_000??_Z0{str(zplanes).zfill(2)}_CH{str(channels)}.tif'
        
        dest = os.path.join(stitch_dir, f"cyc{str(cycles).zfill(2)}", f"CH{str(channels)}")
        os.makedirs(dest, exist_ok=True)
        dest_1 = os.path.join(stitch_dir, f"cyc{str(cycles).zfill(2)}", "CH1")
        
        im_raw = sorted(glob(os.path.join(image_dir, f'cyc{str(cycles).zfill(zeros)}', filename_pattern)), key=alphanumeric_key)
        im = io.imread_collection(im_raw)
        im_array = np.asarray(im)

        if zplanes == zplanes_n//2:

            print(f"im_array shape is {im_array.shape} min: {im_array.min()} max: {im_array.max()}")
            basic = BaSiC(max_workers=max_basic_workers, max_reweight_iterations=30, max_reweight_iterations_baseline=40)
            basic.autotune_hillclimbing(im_array, random_state=0, early_stop=False, histogram_qmin=1-quant, histogram_qmax=quant, search_space={"smoothness_flatfield": list(np.logspace(-1, 1, 8))}, init_params={"smoothness_flatfield": 0.1})
            images_transformed_ff = basic.fit_transform(im_array)
            basic.save_model(os.path.join(dest, "basic_first"), overwrite=True)
            print(f"images_transformed_ff shape is {images_transformed_ff.shape} min: {images_transformed_ff.min()} max: {images_transformed_ff.max()}")

            basic_2 = BaSiC(fitting_mode="approximate", get_darkfield=True, sort_intensity=True, max_workers=max_basic_workers)
            basic_2.autotune_hillclimbing(images_transformed_ff, random_state=0, n_iter=50, early_stop_n_iter_no_change=8, histogram_bins=100, histogram_qmax=0.6,  
                        search_space={"smoothness_flatfield": list(np.logspace(-1, 1, 8)),
                                    "smoothness_darkfield": list(np.logspace(-5, 1, 8)),
                                    "sparse_cost_darkfield": list(np.logspace(-5, 1, 8))},
                        init_params={"smoothness_flatfield": 0.1,
                                    "smoothness_darkfield": 1e-5,
                                    "sparse_cost_darkfield": 1e-5})   
                        
            basic_2.save_model(os.path.join(dest, "basic_second"), overwrite=True)
            
        else: 
            
            basic_3 = BaSiC.load_model(os.path.join(dest, "basic_first"))
            images_transformed_ff2 = basic_3.fit_transform(im_array)
            basic_4 = BaSiC.load_model(os.path.join(dest, "basic_second"))
            images_transformed = basic_4.fit_transform(images_transformed_ff2)
    
        images_transformed = exposure.match_histograms(images_transformed, im_array).astype(np.uint16) 
                                                
        stitch(images_transformed, zplanes, dest, dest_1, channels, zplanes_n, pou, rows, cols, overlap_percentage)

    except Exception as e:
        logger.error(f"Error in apply_basic: {str(e)}")
        raise

# %% [markdown]
# ### 3.3 Running multiple cycle/channels

# %% [markdown]
# This cell runs the above two functions for all the images you define with start_cycle, end_cycle, start_channel, and end_channel.  You must enter these values as well as n, m, pou (determined from the first notebook), zplanes_n (number of zplanes), and overlap_percentage.  You must also enter the number of workers for the multithreading (usually determined by dataset size, available memory, and number of cores).  See https://docs.python.org/3/library/concurrent.futures.html
#
# To run just one cycle or channel, simply enter the same number for both start and end.
#
# If problems with the jupyter kernel restarting becomes an issue, decrease the number of workers, or close other programs to conserve resources.  You can also try reducing the histogram bins, number of iterations, and/or early_stop_n_iter_no_change values.

# %%
# Configure logging
logging.basicConfig(level=logging.DEBUG)
logger = logging.getLogger(__name__)

def generate_snake_pattern(rows: int, cols: int) -> tuple[list, list]:
    """Generate snake pattern coordinates for image stitching."""
    row_coords = list(chain.from_iterable(repeat(row, cols) for row in range(rows)))
    col_coords = list(chain.from_iterable(
        range(cols) if row % 2 == 0 else range(cols - 1, -1, -1) 
        for row in range(rows)))
    return row_coords, col_coords

def process_cycles(
    image_dir: str,
    stitch_dir: str,
    start_cycle: int = 1,
    end_cycle: int = 1,
    start_channel: int = 1,
    end_channel: int = 4,
    pou: int = 13,
    zplanes_n: int = 17,
    overlap_percentage: float = 0.30,
    grid_rows: int = 9,
    grid_cols: int = 7
) -> None:
    """Process multiple cycles and channels with parallel z-plane processing."""
    try:
        # Generate snake pattern
        rows, cols = generate_snake_pattern(grid_rows, grid_cols)
        
        # Prepare parallel processing parameters
        workers = (zplanes_n - 1)
        zplanes_range = list(range(1, zplanes_n//2)) + list(range((zplanes_n//2)+1, zplanes_n+1))
        
        # Create parameter lists
        base_params = {
            'image_dir': [image_dir] * (zplanes_n-1),
            'stitch_dir': [stitch_dir] * (zplanes_n-1),
            'zplanes_n': [zplanes_n] * (zplanes_n-1),
            'pou': [pou] * (zplanes_n-1),
            'rows': [rows] * (zplanes_n-1),
            'cols': [cols] * (zplanes_n-1),
            'overlap_percentage': [overlap_percentage] * (zplanes_n-1)
        }

        for cycle in range(start_cycle, end_cycle + 1):
            for channel in range(start_channel, end_channel + 1):
                logger.info(f"Processing cycle {cycle}, channel {channel}")
                
                # Process middle z-plane first
                mid_zplane = zplanes_n // 2
                apply_basic(image_dir, stitch_dir, mid_zplane, cycle, channel, 
                          zplanes_n, pou, rows, cols, overlap_percentage)
                
                # Process remaining z-planes in parallel
                with ThreadPoolExecutor(max_workers=workers) as executor:
                    futures = []
                    for zplane in zplanes_range:
                        future = executor.submit(
                            apply_basic,
                            image_dir, stitch_dir, zplane, cycle, channel,
                            zplanes_n, pou, rows, cols, overlap_percentage
                        )
                        futures.append(future)
                    
                    # Wait for all tasks to complete
                    for future in futures:
                        future.result()  # This will raise any exceptions that occurred

    except Exception as e:
        logger.error(f"Error processing cycles: {str(e)}")
        raise

if __name__ == '__main__':
    process_cycles(image_dir, stitch_dir)
# Out:
# INFO:__main__:Processing cycle 1, channel 1
# DEBUG:jax._src.xla_bridge:Initializing backend 'interpreter'
# DEBUG:jax._src.xla_bridge:Backend 'interpreter' initialized
# DEBUG:jax._src.xla_bridge:Initializing backend 'cpu'
# DEBUG:jax._src.xla_bridge:Backend 'cpu' initialized
# DEBUG:jax._src.xla_bridge:Initializing backend 'cuda'
# im_array shape is (63, 1440, 1920) min: 0 max: 32121
# DEBUG:jax._src.xla_bridge:Backend 'cuda' initialized
# DEBUG:jax._src.xla_bridge:Initializing backend 'rocm'
# INFO:jax._src.xla_bridge:Unable to initialize backend 'rocm': NOT_FOUND: Could not find registered platform with name: "rocm". Available platform names are: Host Interpreter CUDA
# DEBUG:jax._src.xla_bridge:Initializing backend 'tpu'
# INFO:jax._src.xla_bridge:Unable to initialize backend 'tpu': module 'jaxlib.xla_extension' has no attribute 'get_tpu_client'
# DEBUG:jax._src.xla_bridge:Initializing backend 'plugin'
# INFO:jax._src.xla_bridge:Unable to initialize backend 'plugin': xla_extension has no attributes named get_plugin_device_client. Compile TensorFlow with //tensorflow/compiler/xla/python:enable_plugin_device set to true (defaults to false) to enable this.
# WARNING:jax._src.dispatch:Finished tracing + transforming jit(convert_element_type) in 0.0 sec
# DEBUG:jax._src.interpreters.pxla:Compiling convert_element_type for with global shapes and types [ShapedArray(uint16[63,1,1440,1920])]. Argument mapping: (GSPMDSharding({replicated}),).
# WARNING:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(convert_element_type) in 0.0 sec
# DEBUG:jax._src.xla_bridge:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# WARNING:jax._src.dispatch:Finished XLA compilation of jit(convert_element_type) in 0.021042823791503906 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming <lambda> for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.00099945068359375 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.00099945068359375 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming <lambda> for pjit in 0.0009992122650146484 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming <lambda> for pjit in 0.00099945068359375 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming absolute for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming true_divide for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming <lambda> for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming <lambda> for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _reduce_sum for pjit in 0.0002503395080566406 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming absolute for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming <lambda> for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _broadcast_arrays for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _where for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming true_divide for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _broadcast_arrays for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _where for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming op for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming <lambda> for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming absolute for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming true_divide for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming <lambda> for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming <lambda> for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _reduce_sum for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming true_divide for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _broadcast_arrays for pjit in 0.0010006427764892578 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _where for pjit in 0.0018014907836914062 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _einsum for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _resize for pjit in 0.06612014770507812 sec
# DEBUG:jax._src.interpreters.pxla:Compiling _resize for with global shapes and types [ShapedArray(float32[63,1,1440,1920])]. Argument mapping: (GSPMDSharding({replicated}),).
# WARNING:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(_resize) in 0.01604628562927246 sec
# DEBUG:jax._src.xla_bridge:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# WARNING:jax._src.dispatch:Finished XLA compilation of jit(_resize) in 0.05049324035644531 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming jit(convert_element_type) in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming jit(broadcast_in_dim) in 0.0 sec
# DEBUG:jax._src.interpreters.pxla:Compiling broadcast_in_dim for with global shapes and types [ShapedArray(float32[])]. Argument mapping: (GSPMDSharding({replicated}),).
# WARNING:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(broadcast_in_dim) in 0.0 sec
# DEBUG:jax._src.xla_bridge:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# WARNING:jax._src.dispatch:Finished XLA compilation of jit(broadcast_in_dim) in 0.017691850662231445 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming jit(reshape) in 0.0 sec
# DEBUG:jax._src.interpreters.pxla:Compiling reshape for with global shapes and types [ShapedArray(float32[63,1,128,128])]. Argument mapping: (GSPMDSharding({replicated}),).
# WARNING:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(reshape) in 0.0 sec
# DEBUG:jax._src.xla_bridge:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# WARNING:jax._src.dispatch:Finished XLA compilation of jit(reshape) in 0.005007266998291016 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming svd for pjit in 0.0 sec
# DEBUG:jax._src.interpreters.pxla:Compiling svd for with global shapes and types [ShapedArray(float32[63,16384])]. Argument mapping: (GSPMDSharding({replicated}),).
# WARNING:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(svd) in 0.0 sec
# DEBUG:jax._src.xla_bridge:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# WARNING:jax._src.dispatch:Finished XLA compilation of jit(svd) in 0.023706912994384766 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming jit(convert_element_type) in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming jit(dynamic_slice) in 0.0009996891021728516 sec
# DEBUG:jax._src.interpreters.pxla:Compiling dynamic_slice for with global shapes and types [ShapedArray(float32[63]), ShapedArray(int32[])]. Argument mapping: (GSPMDSharding({replicated}), GSPMDSharding({replicated})).
# WARNING:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(dynamic_slice) in 0.0010004043579101562 sec
# DEBUG:jax._src.xla_bridge:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# WARNING:jax._src.dispatch:Finished XLA compilation of jit(dynamic_slice) in 0.004208087921142578 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming jit(squeeze) in 0.0 sec
# DEBUG:jax._src.interpreters.pxla:Compiling squeeze for with global shapes and types [ShapedArray(float32[1])]. Argument mapping: (GSPMDSharding({replicated}),).
# WARNING:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(squeeze) in 0.0 sec
# DEBUG:jax._src.xla_bridge:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# WARNING:jax._src.dispatch:Finished XLA compilation of jit(squeeze) in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming true_divide for pjit in 0.0 sec
# DEBUG:jax._src.interpreters.pxla:Compiling true_divide for with global shapes and types [ShapedArray(float32[], weak_type=True), ShapedArray(float32[])]. Argument mapping: (GSPMDSharding({replicated}), GSPMDSharding({replicated})).
# WARNING:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(true_divide) in 0.0010957717895507812 sec
# DEBUG:jax._src.xla_bridge:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# WARNING:jax._src.dispatch:Finished XLA compilation of jit(true_divide) in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming true_divide for pjit in 0.0 sec
# DEBUG:jax._src.interpreters.pxla:Compiling true_divide for with global shapes and types [ShapedArray(float32[]), ShapedArray(int32[])]. Argument mapping: (GSPMDSharding({replicated}), GSPMDSharding({replicated})).
# WARNING:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(true_divide) in 0.0012254714965820312 sec
# DEBUG:jax._src.xla_bridge:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# WARNING:jax._src.dispatch:Finished XLA compilation of jit(true_divide) in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.0 sec
# DEBUG:jax._src.interpreters.pxla:Compiling fn for with global shapes and types [ShapedArray(float32[]), ShapedArray(float32[], weak_type=True)]. Argument mapping: (GSPMDSharding({replicated}), GSPMDSharding({replicated})).
# WARNING:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(fn) in 0.0 sec
# DEBUG:jax._src.xla_bridge:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# WARNING:jax._src.dispatch:Finished XLA compilation of jit(fn) in 0.0011038780212402344 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _reduce_min for pjit in 0.0 sec
# DEBUG:jax._src.interpreters.pxla:Compiling _reduce_min for with global shapes and types [ShapedArray(float32[63,1,128,128])]. Argument mapping: (GSPMDSharding({replicated}),).
# WARNING:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(_reduce_min) in 0.0 sec
# DEBUG:jax._src.xla_bridge:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# WARNING:jax._src.dispatch:Finished XLA compilation of jit(_reduce_min) in 0.016733407974243164 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming ravel for pjit in 0.0 sec
# DEBUG:jax._src.interpreters.pxla:Compiling ravel for with global shapes and types [ShapedArray(float32[63,1,128,128])]. Argument mapping: (GSPMDSharding({replicated}),).
# WARNING:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(ravel) in 0.0011925697326660156 sec
# DEBUG:jax._src.xla_bridge:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# WARNING:jax._src.dispatch:Finished XLA compilation of jit(ravel) in 0.0001678466796875 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming conjugate for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming real for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _reduce_sum for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming <lambda> for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming norm for pjit in 0.015894412994384766 sec
# DEBUG:jax._src.interpreters.pxla:Compiling norm for with global shapes and types [ShapedArray(float32[1032192])]. Argument mapping: (GSPMDSharding({replicated}),).
# WARNING:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(norm) in 0.0 sec
# DEBUG:jax._src.xla_bridge:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# WARNING:jax._src.dispatch:Finished XLA compilation of jit(norm) in 0.016856670379638672 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.0 sec
# DEBUG:jax._src.interpreters.pxla:Compiling fn for with global shapes and types [ShapedArray(float32[63,1,128,128]), ShapedArray(float32[63,1,128,128])]. Argument mapping: (GSPMDSharding({replicated}), GSPMDSharding({replicated})).
# WARNING:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(fn) in 0.013159036636352539 sec
# DEBUG:jax._src.xla_bridge:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# WARNING:jax._src.dispatch:Finished XLA compilation of jit(fn) in 0.008893966674804688 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.001001119613647461 sec
# DEBUG:jax._src.interpreters.pxla:Compiling fn for with global shapes and types [ShapedArray(float32[63,1,128,128]), ShapedArray(int32[], weak_type=True)]. Argument mapping: (GSPMDSharding({replicated}), GSPMDSharding({replicated})).
# WARNING:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(fn) in 0.0 sec
# DEBUG:jax._src.xla_bridge:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# WARNING:jax._src.dispatch:Finished XLA compilation of jit(fn) in 0.014587879180908203 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _reduce_sum for pjit in 0.0 sec
# DEBUG:jax._src.interpreters.pxla:Compiling _reduce_sum for with global shapes and types [ShapedArray(float32[63,1,128,128])]. Argument mapping: (GSPMDSharding({replicated}),).
# WARNING:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(_reduce_sum) in 0.0 sec
# DEBUG:jax._src.xla_bridge:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# WARNING:jax._src.dispatch:Finished XLA compilation of jit(_reduce_sum) in 0.018503665924072266 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming true_divide for pjit in 0.0 sec
# DEBUG:jax._src.interpreters.pxla:Compiling true_divide for with global shapes and types [ShapedArray(float32[63,1,128,128]), ShapedArray(float32[])]. Argument mapping: (GSPMDSharding({replicated}), GSPMDSharding({replicated})).
# WARNING:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(true_divide) in 0.0 sec
# DEBUG:jax._src.xla_bridge:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# WARNING:jax._src.dispatch:Finished XLA compilation of jit(true_divide) in 0.009000778198242188 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming jit(broadcast_in_dim) in 0.0 sec
# DEBUG:jax._src.interpreters.pxla:Compiling broadcast_in_dim for with global shapes and types [ShapedArray(float32[])]. Argument mapping: (GSPMDSharding({replicated}),).
# WARNING:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(broadcast_in_dim) in 0.0013625621795654297 sec
# DEBUG:jax._src.xla_bridge:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# WARNING:jax._src.dispatch:Finished XLA compilation of jit(broadcast_in_dim) in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming isnan for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _reduce_any for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _broadcast_arrays for pjit in 0.0011320114135742188 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _where for pjit in 0.0029299259185791016 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming <lambda> for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming quantile for pjit in 0.0167999267578125 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming median for pjit in 0.0167999267578125 sec
# DEBUG:jax._src.interpreters.pxla:Compiling median for with global shapes and types [ShapedArray(float32[63,1,128,128])]. Argument mapping: (GSPMDSharding({replicated}),).
# WARNING:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(median) in 0.0166168212890625 sec
# DEBUG:jax._src.xla_bridge:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# WARNING:jax._src.dispatch:Finished XLA compilation of jit(median) in 0.033566951751708984 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming jit(broadcast_in_dim) in 0.0 sec
# DEBUG:jax._src.interpreters.pxla:Compiling broadcast_in_dim for with global shapes and types [ShapedArray(float32[])]. Argument mapping: (GSPMDSharding({replicated}),).
# WARNING:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(broadcast_in_dim) in 0.0 sec
# DEBUG:jax._src.xla_bridge:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# WARNING:jax._src.dispatch:Finished XLA compilation of jit(broadcast_in_dim) in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming true_divide for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _reduce_any for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _reduce_all for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.01268768310546875 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _reduce_sum for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming <lambda> for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming true_divide for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _reduce_sum for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming true_divide for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _moveaxis for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fft for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _moveaxis for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming true_divide for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming <lambda> for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming true_divide for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming <lambda> for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming <lambda> for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _flip for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming <lambda> for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _broadcast_arrays for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _where for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming remainder for pjit in 0.012962102890014648 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming <lambda> for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _roll for pjit in 0.016263723373413086 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming real for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.0010001659393310547 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming true_divide for pjit in 0.0009992122650146484 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming true_divide for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _moveaxis for pjit in 0.001415252685546875 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fft for pjit in 0.0010013580322265625 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _moveaxis for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming true_divide for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming <lambda> for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming true_divide for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming sign for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming absolute for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming <lambda> for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming <lambda> for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _jshrinkage for pjit in 0.002818584442138672 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming <lambda> for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming true_divide for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming <lambda> for pjit in 0.0010013580322265625 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming true_divide for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _squeeze for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming <lambda> for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _moveaxis for pjit in 0.012508392333984375 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fft for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _moveaxis for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming <lambda> for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming true_divide for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming <lambda> for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming true_divide for pjit in 0.013057470321655273 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _squeeze for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _moveaxis for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fft for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _moveaxis for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _squeeze for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming <lambda> for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.012179374694824219 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming true_divide for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming <lambda> for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming true_divide for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _squeeze for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _squeeze for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming idctnd for pjit in 0.08593273162841797 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _reduce_min for pjit in 0.009757518768310547 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _broadcast_arrays for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _where for pjit in 0.0001380443572998047 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming <lambda> for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming true_divide for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming sign for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming absolute for pjit in 0.0001456737518310547 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming <lambda> for pjit in 0.0010018348693847656 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _jshrinkage for pjit in 0.01570606231689453 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _reduce_sum for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _reduce_sum for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming true_divide for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _broadcast_arrays for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _where for pjit in 0.0023555755615234375 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming <lambda> for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _reduce_sum for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _mean for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming <lambda> for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming ravel for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming conjugate for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming real for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _reduce_sum for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming norm for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming <lambda> for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming ravel for pjit in 0.0002269744873046875 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming conjugate for pjit in 4.1484832763671875e-05 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming real for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _reduce_sum for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming norm for pjit in 0.0011954307556152344 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _reduce_max for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming <lambda> for pjit in 0.0009996891021728516 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _step for pjit in 0.33417367935180664 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _fit_jit for pjit in 0.3523540496826172 sec
# DEBUG:jax._src.interpreters.pxla:Compiling _fit_jit for with global shapes and types [ShapedArray(float32[63,1,128,128]), ShapedArray(float32[63,1,128,128]), ShapedArray(float32[1,128,128]), ShapedArray(float32[1,128,128]), ShapedArray(float32[1,128,128]), ShapedArray(float32[], weak_type=True), ShapedArray(float32[63]), ShapedArray(float32[63,1,128,128]), ShapedArray(float32[63,1,128,128])]. Argument mapping: (GSPMDSharding({replicated}), GSPMDSharding({replicated}), GSPMDSharding({replicated}), GSPMDSharding({replicated}), GSPMDSharding({replicated}), GSPMDSharding({replicated}), GSPMDSharding({replicated}), GSPMDSharding({replicated}), GSPMDSharding({replicated})).
# WARNING:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(_fit_jit) in 0.0602259635925293 sec
# DEBUG:jax._src.xla_bridge:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# WARNING:jax._src.dispatch:Finished XLA compilation of jit(_fit_jit) in 0.3163154125213623 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.0 sec
# DEBUG:jax._src.interpreters.pxla:Compiling fn for with global shapes and types [ShapedArray(float32[], weak_type=True), ShapedArray(float32[1,128,128])]. Argument mapping: (GSPMDSharding({replicated}), GSPMDSharding({replicated})).
# WARNING:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(fn) in 0.0 sec
# DEBUG:jax._src.xla_bridge:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# WARNING:jax._src.dispatch:Finished XLA compilation of jit(fn) in 0.0010418891906738281 sec
# DEBUG:jax._src.interpreters.pxla:Compiling fn for with global shapes and types [ShapedArray(float32[1,128,128]), ShapedArray(float32[1,128,128])]. Argument mapping: (GSPMDSharding({replicated}), GSPMDSharding({replicated})).
# WARNING:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(fn) in 0.0 sec
# DEBUG:jax._src.xla_bridge:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# WARNING:jax._src.dispatch:Finished XLA compilation of jit(fn) in 0.0069997310638427734 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _reduce_sum for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _mean for pjit in 0.001999378204345703 sec
# DEBUG:jax._src.interpreters.pxla:Compiling _mean for with global shapes and types [ShapedArray(float32[1,128,128])]. Argument mapping: (GSPMDSharding({replicated}),).
# WARNING:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(_mean) in 0.0021202564239501953 sec
# DEBUG:jax._src.xla_bridge:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# WARNING:jax._src.dispatch:Finished XLA compilation of jit(_mean) in 0.009000062942504883 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _reduce_max for pjit in 0.00099945068359375 sec
# DEBUG:jax._src.interpreters.pxla:Compiling _reduce_max for with global shapes and types [ShapedArray(float32[1,128,128])]. Argument mapping: (GSPMDSharding({replicated}),).
# WARNING:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(_reduce_max) in 0.0 sec
# DEBUG:jax._src.xla_bridge:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# WARNING:jax._src.dispatch:Finished XLA compilation of jit(_reduce_max) in 0.01720261573791504 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming <lambda> for pjit in 0.0005884170532226562 sec
# DEBUG:jax._src.interpreters.pxla:Compiling <lambda> for with global shapes and types [ShapedArray(float32[]), ShapedArray(int32[], weak_type=True)]. Argument mapping: (GSPMDSharding({replicated}), GSPMDSharding({replicated})).
# WARNING:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(<lambda>) in 0.0 sec
# DEBUG:jax._src.xla_bridge:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# WARNING:jax._src.dispatch:Finished XLA compilation of jit(<lambda>) in 0.006752490997314453 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.0 sec
# DEBUG:jax._src.interpreters.pxla:Compiling fn for with global shapes and types [ShapedArray(float32[1,128,128]), ShapedArray(float32[], weak_type=True)]. Argument mapping: (GSPMDSharding({replicated}), GSPMDSharding({replicated})).
# WARNING:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(fn) in 0.0 sec
# DEBUG:jax._src.xla_bridge:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# WARNING:jax._src.dispatch:Finished XLA compilation of jit(fn) in 0.017238855361938477 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _reduce_sum for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _mean for pjit in 0.0 sec
# DEBUG:jax._src.interpreters.pxla:Compiling _mean for with global shapes and types [ShapedArray(float32[63,1,128,128])]. Argument mapping: (GSPMDSharding({replicated}),).
# WARNING:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(_mean) in 0.0 sec
# DEBUG:jax._src.xla_bridge:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# WARNING:jax._src.dispatch:Finished XLA compilation of jit(_mean) in 0.014685630798339844 sec
# DEBUG:jax._src.interpreters.pxla:Compiling <lambda> for with global shapes and types [ShapedArray(float32[1,128,128]), ShapedArray(float32[1,128,128])]. Argument mapping: (GSPMDSharding({replicated}), GSPMDSharding({replicated})).
# WARNING:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(<lambda>) in 0.00099945068359375 sec
# DEBUG:jax._src.xla_bridge:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# WARNING:jax._src.dispatch:Finished XLA compilation of jit(<lambda>) in 0.007441043853759766 sec
# DEBUG:jax._src.interpreters.pxla:Compiling true_divide for with global shapes and types [ShapedArray(float32[1,128,128]), ShapedArray(float32[])]. Argument mapping: (GSPMDSharding({replicated}), GSPMDSharding({replicated})).
# WARNING:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(true_divide) in 0.0 sec
# DEBUG:jax._src.xla_bridge:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# WARNING:jax._src.dispatch:Finished XLA compilation of jit(true_divide) in 0.0050051212310791016 sec
# DEBUG:jax._src.interpreters.pxla:Compiling fn for with global shapes and types [ShapedArray(float32[63,1,128,128]), ShapedArray(float32[], weak_type=True)]. Argument mapping: (GSPMDSharding({replicated}), GSPMDSharding({replicated})).
# WARNING:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(fn) in 0.0014331340789794922 sec
# DEBUG:jax._src.xla_bridge:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# WARNING:jax._src.dispatch:Finished XLA compilation of jit(fn) in 0.012955427169799805 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming true_divide for pjit in 0.0 sec
# DEBUG:jax._src.interpreters.pxla:Compiling true_divide for with global shapes and types [ShapedArray(float32[63,1,128,128]), ShapedArray(float32[63,1,128,128])]. Argument mapping: (GSPMDSharding({replicated}), GSPMDSharding({replicated})).
# WARNING:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(true_divide) in 0.0 sec
# DEBUG:jax._src.xla_bridge:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# WARNING:jax._src.dispatch:Finished XLA compilation of jit(true_divide) in 0.005402088165283203 sec
# DEBUG:jax._src.interpreters.pxla:Compiling absolute for with global shapes and types [ShapedArray(float32[63,1,128,128])]. Argument mapping: (GSPMDSharding({replicated}),).
# WARNING:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(absolute) in 0.002000093460083008 sec
# DEBUG:jax._src.xla_bridge:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# WARNING:jax._src.dispatch:Finished XLA compilation of jit(absolute) in 0.009775161743164062 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _reduce_sum for pjit in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _mean for pjit in 0.0024361610412597656 sec
# DEBUG:jax._src.interpreters.pxla:Compiling _mean for with global shapes and types [ShapedArray(float32[63,1,128,128])]. Argument mapping: (GSPMDSharding({replicated}),).
# WARNING:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(_mean) in 0.0 sec
# DEBUG:jax._src.xla_bridge:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# WARNING:jax._src.dispatch:Finished XLA compilation of jit(_mean) in 0.018067598342895508 sec
# DEBUG:jax._src.interpreters.pxla:Compiling absolute for with global shapes and types [ShapedArray(float32[1,128,128])]. Argument mapping: (GSPMDSharding({replicated}),).
# WARNING:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(absolute) in 0.0010006427764892578 sec
# DEBUG:jax._src.xla_bridge:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# WARNING:jax._src.dispatch:Finished XLA compilation of jit(absolute) in 0.006999492645263672 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming true_divide for pjit in 0.0 sec
# DEBUG:jax._src.interpreters.pxla:Compiling true_divide for with global shapes and types [ShapedArray(float32[1,128,128]), ShapedArray(float32[1,128,128])]. Argument mapping: (GSPMDSharding({replicated}), GSPMDSharding({replicated})).
# WARNING:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(true_divide) in 6.29425048828125e-05 sec
# DEBUG:jax._src.xla_bridge:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# WARNING:jax._src.dispatch:Finished XLA compilation of jit(true_divide) in 0.0 sec
# DEBUG:jax._src.interpreters.pxla:Compiling _reduce_min for with global shapes and types [ShapedArray(float32[1,128,128])]. Argument mapping: (GSPMDSharding({replicated}),).
# WARNING:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(_reduce_min) in 0.0018341541290283203 sec
# DEBUG:jax._src.xla_bridge:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# WARNING:jax._src.dispatch:Finished XLA compilation of jit(_reduce_min) in 0.0 sec
# flatfield shape: (1, 128, 128) min: 0.5860825777053833 max: 1.2630465030670166
# darkfield shape: (1, 128, 128) min: 0.0 max: 0.0
# DEBUG:jax._src.interpreters.pxla:Compiling _reduce_sum for with global shapes and types [ShapedArray(float32[1,128,128])]. Argument mapping: (GSPMDSharding({replicated}),).
# WARNING:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(_reduce_sum) in 0.001001119613647461 sec
# DEBUG:jax._src.xla_bridge:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# WARNING:jax._src.dispatch:Finished XLA compilation of jit(_reduce_sum) in 0.010007858276367188 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming true_divide for pjit in 0.0 sec
# DEBUG:jax._src.interpreters.pxla:Compiling true_divide for with global shapes and types [ShapedArray(float32[]), ShapedArray(float32[])]. Argument mapping: (GSPMDSharding({replicated}), GSPMDSharding({replicated})).
# WARNING:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(true_divide) in 0.0009975433349609375 sec
# DEBUG:jax._src.xla_bridge:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# WARNING:jax._src.dispatch:Finished XLA compilation of jit(true_divide) in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.0 sec
# DEBUG:jax._src.interpreters.pxla:Compiling fn for with global shapes and types [ShapedArray(float32[]), ShapedArray(float32[], weak_type=True)]. Argument mapping: (GSPMDSharding({replicated}), GSPMDSharding({replicated})).
# WARNING:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(fn) in 0.002148151397705078 sec
# DEBUG:jax._src.xla_bridge:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# WARNING:jax._src.dispatch:Finished XLA compilation of jit(fn) in 0.0 sec
# flatfield shape: (1, 128, 128) min: 0.572520911693573 max: 1.2841439247131348
# darkfield shape: (1, 128, 128) min: 0.0 max: 0.0
# WARNING:jax._src.dispatch:Finished tracing + transforming jit(convert_element_type) in 0.0 sec
# DEBUG:jax._src.interpreters.pxla:Compiling convert_element_type for with global shapes and types [ShapedArray(int32[])]. Argument mapping: (GSPMDSharding({replicated}),).
# WARNING:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(convert_element_type) in 0.0 sec
# DEBUG:jax._src.xla_bridge:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# WARNING:jax._src.dispatch:Finished XLA compilation of jit(convert_element_type) in 0.0 sec
# DEBUG:jax._src.interpreters.pxla:Compiling fn for with global shapes and types [ShapedArray(int32[], weak_type=True), ShapedArray(int32[], weak_type=True)]. Argument mapping: (GSPMDSharding({replicated}), GSPMDSharding({replicated})).
# WARNING:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(fn) in 0.0 sec
# DEBUG:jax._src.xla_bridge:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# WARNING:jax._src.dispatch:Finished XLA compilation of jit(fn) in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming fn for pjit in 0.0009999275207519531 sec
# DEBUG:jax._src.interpreters.pxla:Compiling fn for with global shapes and types [ShapedArray(int32[], weak_type=True), ShapedArray(int32[])]. Argument mapping: (GSPMDSharding({replicated}), GSPMDSharding({replicated})).
# WARNING:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(fn) in 0.0 sec
# DEBUG:jax._src.xla_bridge:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# WARNING:jax._src.dispatch:Finished XLA compilation of jit(fn) in 0.0 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming jit(select_n) in 0.0 sec
# DEBUG:jax._src.interpreters.pxla:Compiling select_n for with global shapes and types [ShapedArray(bool[], weak_type=True), ShapedArray(int32[], weak_type=True), ShapedArray(int32[])]. Argument mapping: (GSPMDSharding({replicated}), GSPMDSharding({replicated}), GSPMDSharding({replicated})).
# WARNING:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(select_n) in 0.0009980201721191406 sec
# DEBUG:jax._src.xla_bridge:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# WARNING:jax._src.dispatch:Finished XLA compilation of jit(select_n) in 0.005062580108642578 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming jit(dynamic_slice) in 0.0 sec
# DEBUG:jax._src.interpreters.pxla:Compiling dynamic_slice for with global shapes and types [ShapedArray(float32[1,128,128]), ShapedArray(int32[]), ShapedArray(int32[]), ShapedArray(int32[])]. Argument mapping: (GSPMDSharding({replicated}), GSPMDSharding({replicated}), GSPMDSharding({replicated}), GSPMDSharding({replicated})).
# WARNING:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(dynamic_slice) in 0.0 sec
# DEBUG:jax._src.xla_bridge:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# WARNING:jax._src.dispatch:Finished XLA compilation of jit(dynamic_slice) in 0.015431880950927734 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming jit(squeeze) in 0.0 sec
# DEBUG:jax._src.interpreters.pxla:Compiling squeeze for with global shapes and types [ShapedArray(float32[1,128,128])]. Argument mapping: (GSPMDSharding({replicated}),).
# WARNING:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(squeeze) in 0.0 sec
# DEBUG:jax._src.xla_bridge:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# WARNING:jax._src.dispatch:Finished XLA compilation of jit(squeeze) in 0.015766143798828125 sec
# [0] fit_and_calc_entropy (Hill Climbing):   0%|          | 0/100 [00:00<?, ?it/s]
# flatfield shape: (1, 128, 128) min: 0.5860825777053833 max: 1.2630465030670166
# darkfield shape: (1, 128, 128) min: 0.0 max: 0.0
# flatfield shape: (1, 128, 128) min: 0.572520911693573 max: 1.2841439247131348
# darkfield shape: (1, 128, 128) min: 0.0 max: 0.0
# transformed shape is (63, 1440, 1920) min: 0.0 max: 29779.0625
# [0] fit_and_calc_entropy (Hill Climbing):   8%|          | 8/100 [00:04<06:52,  4.48s/it, best_iter=0, best_pos=[0], best_score=-13.176413939227249]WARNING:jax._src.dispatch:Finished tracing + transforming _step for pjit in 0.021561384201049805 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _fit_jit for pjit in 0.037947654724121094 sec
# DEBUG:jax._src.interpreters.pxla:Compiling _fit_jit for with global shapes and types [ShapedArray(float32[63,1,128,128]), ShapedArray(float32[63,1,128,128]), ShapedArray(float32[1,128,128]), ShapedArray(float32[1,128,128]), ShapedArray(float32[1,128,128]), ShapedArray(float32[], weak_type=True), ShapedArray(float32[63]), ShapedArray(float32[63,1,128,128]), ShapedArray(float32[63,1,128,128])]. Argument mapping: (GSPMDSharding({replicated}), GSPMDSharding({replicated}), GSPMDSharding({replicated}), GSPMDSharding({replicated}), GSPMDSharding({replicated}), GSPMDSharding({replicated}), GSPMDSharding({replicated}), GSPMDSharding({replicated}), GSPMDSharding({replicated})).
# WARNING:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(_fit_jit) in 0.05969595909118652 sec
# DEBUG:jax._src.xla_bridge:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# WARNING:jax._src.dispatch:Finished XLA compilation of jit(_fit_jit) in 0.333498477935791 sec
# flatfield shape: (1, 128, 128) min: 0.6108756065368652 max: 1.1969027519226074
# darkfield shape: (1, 128, 128) min: 0.0 max: 0.0
# transformed shape is (63, 1440, 1920) min: 0.0 max: 29714.10546875
# [0] fit_and_calc_entropy (Hill Climbing):   9%|          | 9/100 [00:08<01:15,  1.20it/s, best_iter=0, best_pos=[1], best_score=-11.001629535254146]WARNING:jax._src.dispatch:Finished tracing + transforming _step for pjit in 0.015625 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming _fit_jit for pjit in 0.03125452995300293 sec
# ...
# WARNING:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(fn) in 0.0 sec
# DEBUG:jax._src.xla_bridge:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# WARNING:jax._src.dispatch:Finished XLA compilation of jit(fn) in 0.014609098434448242 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming true_divide for pjit in 0.0 sec
# DEBUG:jax._src.interpreters.pxla:Compiling true_divide for with global shapes and types [ShapedArray(float32[63,1,1]), ShapedArray(float32[63,128,128])]. Argument mapping: (GSPMDSharding({replicated}), GSPMDSharding({replicated})).
# WARNING:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(true_divide) in 0.0 sec
# DEBUG:jax._src.xla_bridge:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# WARNING:jax._src.dispatch:Finished XLA compilation of jit(true_divide) in 0.015688180923461914 sec
# WARNING:jax._src.dispatch:Finished tracing + transforming true_divide for pjit in 0.0 sec
# DEBUG:jax._src.interpreters.pxla:Compiling true_divide for with global shapes and types [ShapedArray(float32[], weak_type=True), ShapedArray(float32[63,128,128])]. Argument mapping: (GSPMDSharding({replicated}), GSPMDSharding({replicated})).
# WARNING:jax._src.dispatch:Finished jaxpr to MLIR module conversion jit(true_divide) in 0.0 sec
# DEBUG:jax._src.xla_bridge:get_compile_options: num_replicas=1 num_partitions=1 device_assignment=[[CpuDevice(id=0)]]
# WARNING:jax._src.dispatch:Finished XLA compilation of jit(true_divide) in 0.009026050567626953 sec
# c:\Users\smith6jt\AppData\Local\miniforge3\envs\KINTSUGI\lib\site-packages\skimage\transform\_warps.py:725: RuntimeWarning: All-NaN slice encountered
#   min_val = min_func(input_image)
# c:\Users\smith6jt\AppData\Local\miniforge3\envs\KINTSUGI\lib\site-packages\skimage\transform\_warps.py:729: RuntimeWarning: All-NaN slice encountered
#   max_val = max_func(input_image)
# [0] fit_and_calc_entropy (Hill Climbing):   0%|          | 0/50 [00:00<?, ?it/s]WARNING:basicpy.basicpy:Reweighting did not converge.
# flatfield shape: (1, 128, 128) min: nan max: nan
# darkfield shape: (1, 128, 128) min: nan max: nan
# flatfield shape: (1, 128, 128) min: nan max: nan
# darkfield shape: (1, 128, 128) min: nan max: nan
# flatfield shape: (1, 128, 128) min: nan max: nan
# darkfield shape: (1, 128, 128) min: nan max: nan
# flatfield shape: (1, 128, 128) min: nan max: nan
# darkfield shape: (1, 128, 128) min: nan max: nan
# flatfield shape: (1, 128, 128) min: nan max: nan
# darkfield shape: (1, 128, 128) min: nan max: nan
# flatfield shape: (1, 128, 128) min: nan max: nan
# darkfield shape: (1, 128, 128) min: nan max: nan
# flatfield shape: (1, 128, 128) min: nan max: nan
# darkfield shape: (1, 128, 128) min: nan max: nan
# flatfield shape: (1, 128, 128) min: nan max: nan
# darkfield shape: (1, 128, 128) min: nan max: nan
# flatfield shape: (1, 128, 128) min: nan max: nan
# darkfield shape: (1, 128, 128) min: nan max: nan
# flatfield shape: (1, 128, 128) min: nan max: nan
# darkfield shape: (1, 128, 128) min: nan max: nan
# ERROR:__main__:Error in apply_basic: supplied range of [nan, nan] is not finite
# transformed shape is (63, 1440, 1920) min: nan max: nan
# ERROR:__main__:Error processing cycles: supplied range of [nan, nan] is not finite
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 75
#      72         raise
#      74 if __name__ == '__main__':
# ---> 75     process_cycles(image_dir, stitch_dir)
#
# Cell In[5], line 52, in process_cycles(image_dir, stitch_dir, start_cycle, end_cycle, start_channel, end_channel, pou, zplanes_n, overlap_percentage, grid_rows, grid_cols)
#      50 # Process middle z-plane first
#      51 mid_zplane = zplanes_n // 2
# ---> 52 apply_basic(image_dir, stitch_dir, mid_zplane, cycle, channel,
#      53           zplanes_n, pou, rows, cols, overlap_percentage)
#      55 # Process remaining z-planes in parallel
#      56 with ThreadPoolExecutor(max_workers=workers) as executor:
#
# Cell In[4], line 28, in apply_basic(image_dir, stitch_dir, zplanes, cycles, channels, zplanes_n, pou, rows, cols, overlap_percentage)
#      25     print(f"images_transformed_ff shape is {images_transformed_ff.shape} min: {images_transformed_ff.min()} max: {images_transformed_ff.max()}")
#      27     basic_2 = BaSiC(fitting_mode="approximate", smoothness_flatfield=0.1, get_darkfield=True, sort_intensity=True, max_workers=max_basic_workers)
# ---> 28     basic_2.autotune_hillclimbing(images_transformed_ff, random_state=0, n_iter=50, early_stop_n_iter_no_change=8, histogram_bins=100, histogram_qmax=0.6,
#      29                 search_space={"smoothness_flatfield": list(np.logspace(-1, 1, 8)),
#      30                             "smoothness_darkfield": list(np.logspace(-5, 1, 8)),
#      31                             "sparse_cost_darkfield": list(np.logspace(-5, 1, 8))},
#      32                 init_params={"smoothness_flatfield": 0.1,
#      33                             "smoothness_darkfield": 1e-5,
#      34                             "sparse_cost_darkfield": 1e-5})
#      36     basic_2.save_model(os.path.join(dest, "basic_second"), overwrite=True)
#      38 else:
#
# File c:\Users\smith6jt\AppData\Local\miniforge3\envs\KINTSUGI\lib\site-packages\basicpy\basicpy.py:1048, in BaSiC.autotune_hillclimbing(self, images, fitting_weight, skip_shape_warning, optmizer, n_iter, search_space, init_params, timelapse, histogram_qmin, histogram_qmax, vmin_factor, vrange_factor, histogram_bins, histogram_use_fitting_weight, fourier_l0_norm_image_threshold, fourier_l0_norm_fourier_radius, fourier_l0_norm_threshold, fourier_l0_norm_cost_coef, early_stop, early_stop_n_iter_no_change, early_stop_torelance, random_state)
#    1034     params.update(
#    1035         dict(
#    1036             early_stopping=dict(
#    (...)
#    1040         )
#    1041     )
#    1043 hyper.add_search(
#    1044     fit_and_calc_entropy,
#    1045     search_space,
#    1046     **params,
#    1047 )
# -> 1048 hyper.run()
#    1049 best_params = hyper.best_para(fit_and_calc_entropy)
#    1050 self.__dict__.update(best_params)
#
# File c:\Users\smith6jt\AppData\Local\miniforge3\envs\KINTSUGI\lib\site-packages\hyperactive\hyperactive.py:164, in Hyperactive.run(self, max_time)
#     161 for opt in self.opt_pros.values():
#     162     opt.max_time = max_time
# --> 164 self.results_list = run_search(
#     165     self.opt_pros, self.distribution, self.n_processes
#     166 )
#     168 self.results_ = Results(self.results_list, self.opt_pros)
#     170 self._print_info()
#
# File c:\Users\smith6jt\AppData\Local\miniforge3\envs\KINTSUGI\lib\site-packages\hyperactive\run_search.py:51, in run_search(opt_pros, distribution, n_processes)
#      48     n_processes = len(process_infos)
#      50 if n_processes == 1:
# ---> 51     results_list = single_process(_process_, process_infos)
#      52 else:
#      53     (distribution, process_func), dist_paras = _get_distribution(distribution)
#
# File c:\Users\smith6jt\AppData\Local\miniforge3\envs\KINTSUGI\lib\site-packages\hyperactive\distribution.py:9, in single_process(process_func, process_infos)
#       8 def single_process(process_func, process_infos):
# ----> 9     results = [process_func(*info) for info in process_infos]
#      11     return results
#
# File c:\Users\smith6jt\AppData\Local\miniforge3\envs\KINTSUGI\lib\site-packages\hyperactive\distribution.py:9, in <listcomp>(.0)
#       8 def single_process(process_func, process_infos):
# ----> 9     results = [process_func(*info) for info in process_infos]
#      11     return results
#
# File c:\Users\smith6jt\AppData\Local\miniforge3\envs\KINTSUGI\lib\site-packages\hyperactive\process.py:20, in _process_(nth_process, optimizer)
#      17 else:
#      18     p_bar = None
# ---> 20 optimizer.search(nth_process, p_bar)
#      22 if p_bar:
#      23     p_bar.colour = "GREEN"
#
# File c:\Users\smith6jt\AppData\Local\miniforge3\envs\KINTSUGI\lib\site-packages\hyperactive\optimizers\hyper_optimizer.py:148, in HyperOptimizer.search(self, nth_process, p_bar)
#     137 if p_bar:
#     138     p_bar.set_description(
#     139         "["
#     140         + str(nth_process)
#    (...)
#     145         + ")",
#     146     )
# --> 148 self.gfo_optimizer.search_step(nth_iter)
#     149 if self.gfo_optimizer.stop.check():
#     150     break
#
# File c:\Users\smith6jt\AppData\Local\miniforge3\envs\KINTSUGI\lib\site-packages\gradient_free_optimizers\search.py:184, in Search.search_step(self, nth_iter)
#     181 self.nth_iter = nth_iter
#     183 if self.nth_iter < self.n_inits_norm:
# --> 184     self._initialization()
#     186 if self.nth_iter == self.n_init_search:
#     187     self.finish_initialization()
#
# File c:\Users\smith6jt\AppData\Local\miniforge3\envs\KINTSUGI\lib\site-packages\gradient_free_optimizers\times_tracker.py:27, in TimesTracker.iter_time.<locals>.wrapper(self, *args, **kwargs)
#      25 def wrapper(self, *args, **kwargs):
#      26     t = time.time()
# ---> 27     res = func(self, *args, **kwargs)
#      28     self.iter_times.append(time.time() - t)
#      29     return res
#
# File c:\Users\smith6jt\AppData\Local\miniforge3\envs\KINTSUGI\lib\site-packages\gradient_free_optimizers\search.py:41, in Search._initialization(self)
#      37 self.best_score = self.p_bar.score_best
#      39 init_pos = self.init_pos()
# ---> 41 score_new = self._score(init_pos)
#      42 self.evaluate_init(score_new)
#      44 self.pos_l.append(init_pos)
#
# File c:\Users\smith6jt\AppData\Local\miniforge3\envs\KINTSUGI\lib\site-packages\gradient_free_optimizers\times_tracker.py:18, in TimesTracker.eval_time.<locals>.wrapper(self, *args, **kwargs)
#      16 def wrapper(self, *args, **kwargs):
#      17     t = time.time()
# ---> 18     res = func(self, *args, **kwargs)
#      19     self.eval_times.append(time.time() - t)
#      20     return res
#
# File c:\Users\smith6jt\AppData\Local\miniforge3\envs\KINTSUGI\lib\site-packages\gradient_free_optimizers\search.py:33, in Search._score(self, pos)
#      31 @TimesTracker.eval_time
#      32 def _score(self, pos):
# ---> 33     return self.score(pos)
#
# File c:\Users\smith6jt\AppData\Local\miniforge3\envs\KINTSUGI\lib\site-packages\gradient_free_optimizers\results_manager.py:33, in ResultsManager.score.<locals>._wrapper(pos)
#      31 value = self.conv.position2value(pos)
#      32 para = self.conv.value2para(value)
# ---> 33 results_dict = self._obj_func_results(objective_function, para)
#      35 self.results_list.append({**results_dict, **para})
#      37 return results_dict["score"]
#
# File c:\Users\smith6jt\AppData\Local\miniforge3\envs\KINTSUGI\lib\site-packages\gradient_free_optimizers\results_manager.py:16, in ResultsManager._obj_func_results(self, objective_function, para)
#      15 def _obj_func_results(self, objective_function, para):
# ---> 16     results = objective_function(para)
#      18     if isinstance(results, tuple):
#      19         score = results[0]
#
# File c:\Users\smith6jt\AppData\Local\miniforge3\envs\KINTSUGI\lib\site-packages\gradient_free_optimizers\memory.py:56, in Memory.memory.<locals>.wrapper(para)
#      54     return self.memory_dict[pos_tuple]
#      55 else:
# ---> 56     score = objective_function(para)
#      57     self.memory_dict[pos_tuple] = score
#      58     self.memory_dict_new[pos_tuple] = score
#
# File c:\Users\smith6jt\AppData\Local\miniforge3\envs\KINTSUGI\lib\site-packages\hyperactive\optimizers\objective_function.py:43, in ObjectiveFunction.__call__.<locals>._model(para)
#      41 try:
#      42     self.run_callbacks("before")
# ---> 43     results = self.objective_function(self)
#      44     self.run_callbacks("after")
#      45 except tuple(self.catch.keys()) as e:
#
# File c:\Users\smith6jt\AppData\Local\miniforge3\envs\KINTSUGI\lib\site-packages\basicpy\basicpy.py:1000, in BaSiC.autotune_hillclimbing.<locals>.fit_and_calc_entropy(params)
#     997     if np.allclose(basic.flatfield, np.ones_like(basic.flatfield)):
#     998         return -np.inf  # discard the case where flatfield is all ones
# -> 1000     return -1.0 * autotune_cost(
#    1001         transformed,
#    1002         basic.flatfield,
#    1003         entropy_vmin=vmin_new,
#    1004         entropy_vmax=vmin_new + val_range,
#    1005         histogram_bins=histogram_bins,
#    1006         fourier_l0_norm_cost_coef=fourier_l0_norm_cost_coef,
#    1007         fourier_l0_norm_image_threshold=fourier_l0_norm_image_threshold,
#    1008         fourier_l0_norm_fourier_radius=fourier_l0_norm_fourier_radius,
#    1009         fourier_l0_norm_threshold=fourier_l0_norm_threshold,
#    1010         weights=weights,
#    1011     )
#    1013 except RuntimeError:
#    1014     return -np.inf
#
# File c:\Users\smith6jt\AppData\Local\miniforge3\envs\KINTSUGI\lib\site-packages\basicpy\metrics.py:110, in autotune_cost(transformed_image, flatfield, entropy_vmin, entropy_vmax, histogram_bins, fourier_l0_norm_image_threshold, fourier_l0_norm_fourier_radius, fourier_l0_norm_threshold, fourier_l0_norm_cost_coef, weights)
#      74 def autotune_cost(
#      75     transformed_image: np.ndarray,
#      76     flatfield: np.ndarray,
#    (...)
#      84     weights: Optional[np.ndarray] = None,
#      85 ):
#      86     """Calculate the cost function for autotuning.
#      87
#      88     Parameters
#    (...)
#     108
#     109     """
# --> 110     entropy_value = entropy(
#     111         transformed_image,
#     112         vmin=entropy_vmin,
#     113         vmax=entropy_vmax,
#     114         bins=histogram_bins,
#     115         weights=weights,
#     116         clip=True,
#     117     )
#     119     n = fourier_L0_norm(
#     120         flatfield,
#     121         fourier_l0_norm_image_threshold,
#     122         fourier_l0_norm_fourier_radius,
#     123         exclude_edges=True,
#     124     )
#     126     if n < fourier_l0_norm_threshold:
#
# File c:\Users\smith6jt\AppData\Local\miniforge3\envs\KINTSUGI\lib\site-packages\basicpy\metrics.py:45, in entropy(image, vmin, vmax, bins, weights, clip)
#      42     if weights is not None:
#      43         weights = weights[ind]
# ---> 45 prob_density, edges = np.histogram(
#      46     image, bins=bins, range=(vmin, vmax), weights=weights, density=True
#      47 )
#      48 # density : p(x) ... normalized such that the integral over the range is 1
#      49 dx = edges[1] - edges[0]
#
# File <__array_function__ internals>:180, in histogram(*args, **kwargs)
#
# File c:\Users\smith6jt\AppData\Local\miniforge3\envs\KINTSUGI\lib\site-packages\numpy\lib\histograms.py:793, in histogram(a, bins, range, normed, weights, density)
#     681 r"""
#     682 Compute the histogram of a dataset.
#     683
#    (...)
#     789
#     790 """
#     791 a, weights = _ravel_and_check_weights(a, weights)
# --> 793 bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
#     795 # Histogram is an integer or a float array depending on the weights.
#     796 if weights is None:
#
# File c:\Users\smith6jt\AppData\Local\miniforge3\envs\KINTSUGI\lib\site-packages\numpy\lib\histograms.py:426, in _get_bin_edges(a, bins, range, weights)
#     423     if n_equal_bins < 1:
#     424         raise ValueError('`bins` must be positive, when an integer')
# --> 426     first_edge, last_edge = _get_outer_edges(a, range)
#     428 elif np.ndim(bins) == 1:
#     429     bin_edges = np.asarray(bins)
#
# File c:\Users\smith6jt\AppData\Local\miniforge3\envs\KINTSUGI\lib\site-packages\numpy\lib\histograms.py:315, in _get_outer_edges(a, range)
#     312         raise ValueError(
#     313             'max must be larger than min in range parameter.')
#     314     if not (np.isfinite(first_edge) and np.isfinite(last_edge)):
# --> 315         raise ValueError(
#     316             "supplied range of [{}, {}] is not finite".format(first_edge, last_edge))
#     317 elif a.size == 0:
#     318     # handle empty arrays. Can't determine range, so use 0-1.
#     319     first_edge, last_edge = 0, 1
#
# ValueError: supplied range of [nan, nan] is not finite

# %%
n = 9  # Number of rows (height)
m = 7  # Number of columns (width)

# Row coordinates: each row index is repeated m times
rows = list(chain.from_iterable(repeat(row, m) for row in range(n)))
# Column coordinates: snake pattern for each row, going back and forth from top left going right
cols = list(chain.from_iterable(range(m) if row % 2 == 0 else range(m - 1, -1, -1) for row in range(n)))

start_cycle = 1
end_cycle = 1
start_channel = 2
end_channel = 4
pou = 13
zplanes_n = 17
overlap_percentage = 0.30
workers = (zplanes_n-1)//2

image_dir_list = [image_dir] * (zplanes_n-1)
stitch_dir_list = [stitch_dir] * (zplanes_n-1)
zplanes_list =[zplanes_n] * (zplanes_n-1)
pou_list = [pou] * (zplanes_n-1)
rows_list = [rows] * (zplanes_n-1)
cols_list = [cols] * (zplanes_n-1)
overlap_percentage_list = [overlap_percentage] * (zplanes_n-1)


for j in range(start_cycle, end_cycle+1):
    for i in range(start_channel, end_channel+1):

        cycles = j
        zplanes = zplanes_n//2 
        channels = i
        apply_basic(image_dir, stitch_dir, zplanes, cycles, channels, zplanes_n, pou, rows, cols, overlap_percentage)
        
        if __name__ ==  '__main__':
            with ThreadPoolExecutor(max_workers=workers) as executor:
                cycles = [j] * (zplanes_n-1) 
                zplanes =  list(range(1, zplanes_n//2))+list(range((zplanes_n//2)+1, zplanes_n+1)) 
                channels = [i] * (zplanes_n-1)
                executor.map(apply_basic, image_dir_list, stitch_dir_list, zplanes, cycles, channels, zplanes_list, pou_list, rows_list, cols_list, overlap_percentage_list)

# %% [markdown]
# ### 4. Deconvolution

# %% [markdown]
# Before moving on to the deconvolution step, it is a good idea to review the results thus far.  If they are satisfactory, the parameters for deconvolution discovered in the first notebook can be entered below to define the decon function. Also, if more or all of the cycles have now been stitched, more deconvolution testing can be done on these stacks in the previous notebook before proceeding to a larger run.
#
# Be sure the MATLAB Runtime v9.5 (R2018, 64-bit) is installed.  Download for free here: http://www.mathworks.com/products/compiler/mcr/index.html. Reboot your computer after install.
#
# There is no need to supply a point-spread function.
#
# The base_dir and stitch_dir definitions used previously will be again used here, and a new folder will be created to save the deconvolved images.
#
# The original deconvolution program was written specifically for lightsheet images. Here the estimation of the point-spread function was modified for use with widefield fluorescence images.  See https://www.nature.com/articles/s41598-019-53875-y for the original publication which includes links to the original code.
#
# Output will be written to the terminal.  Check that the first image stack is processed without error.  If there is an "Maximum variable size allowed on the device is exceeded." error, then restart the kernel, decrease the max_GPU or max_CPU parameter, rerun the decon function cell, and try again.

# %% [markdown]
# ### 4.1 Deconvolution Function

# %%
def decon(cycles, channels):
    
    c = str(cycles)
    ch = str(channels)

    # pixel size in xy dimension (nanometers)
    xy_vox = 377
    # pixel size in z dimension (nanometers)
    z_vox = 1500
    # Number of iterations of Lucy-Richardson algo before stopping unless stop_crit is met first
    iterations = 100
    # Microscope objective numerical aperture
    mic_NA = 0.75
    # Refractive index of tissue being imaged
    tissue_RI = 1.3
    # Opening size in millimeters of objective aperture
    slit_aper = 6.5
    # Focal length in millimeters of objective
    f_cyl = 1
    # Used to reduce noise.  Increase value for noisy images. (0-10)
    damping = 0
    # If set, the deconvolved images will be clipped by this percent for max and min values, and then scaled to full range of bit depth. (0-5)
    hist_clip = 0.000
    # Percent change between iterations to use as criteria to stop deconvolution.
    stop_crit = 5.00
    # Enter 1 to perform on GPU, 0 to use CPU
    GPU = 1
    # Percent maximum GPU memory to use if GPU = 1
    max_GPU = 25
    # Percent maximum RAM to use if GPU = 0
    max_CPU = 40
    if GPU == 1:
        max_block=max_GPU
    elif GPU == 0:
        max_block=max_CPU

    # The respective excitation and emission wavelength in nanometers for each channel
    C1ex = 358
    C1em = 461
    C2ex = 753
    C2em = 775
    C3ex = 560
    C3em = 575
    C4ex = 648
    C4em = 668
    
    # The path to the deconvolution executable file.
    decon_exe = "C:/Users/smith6jt/KINTSUGI/LsDeconv.exe"
    stitch_dir = "C:/Users/smith6jt/KINTSUGI/data/1904_CC2B28_BaSiC_Stitched"
    decon_dir = stitch_dir.replace('_BaSiC_Stitched', '_Decon')
    source = os.path.join(stitch_dir, f"cyc{c.zfill(2)}", f"CH{ch}")
    dest = os.path.join(decon_dir, f"cyc{c.zfill(2)}", f"CH{ch}")
    os.makedirs(dest, exist_ok=True)

    print(f"Starting Deconvolution of cyc{c.zfill(2)} CH{ch}")
   
    if channels==1:
        subprocess.run([decon_exe, source, str(xy_vox), str(z_vox), str(iterations), str(mic_NA), str(tissue_RI), str(C1ex), str(C1em), str(f_cyl), str(slit_aper), str(damping), str(hist_clip), str(stop_crit), str(max_block), str(GPU)])
        # print(result_1.stdout)
    if channels==2:
        subprocess.run([decon_exe, source, str(xy_vox), str(z_vox), str(iterations), str(mic_NA), str(tissue_RI), str(C2ex), str(C2em), str(f_cyl), str(slit_aper), str(damping), str(hist_clip), str(stop_crit), str(max_block), str(GPU)])
    if channels==3:
        subprocess.run([decon_exe, source, str(xy_vox), str(z_vox), str(iterations), str(mic_NA), str(tissue_RI), str(C3ex), str(C3em), str(f_cyl), str(slit_aper), str(damping), str(hist_clip), str(stop_crit), str(max_block), str(GPU)])
    if channels==4:
        subprocess.run([decon_exe, source, str(xy_vox), str(z_vox), str(iterations), str(mic_NA), str(tissue_RI), str(C4ex), str(C4em), str(f_cyl), str(slit_aper), str(damping), str(hist_clip), str(stop_crit), str(max_block), str(GPU)])
    # gc.collect()
    
    try:
        os.rename(os.path.join(source, 'deconvolved'), os.path.join(dest, 'deconvolved'))
    except (FileNotFoundError):
        print("Reduce max memory.")

# %% [markdown]
# To apply the above decon function to multiple cycles/channels, enter the start and end numbers below.

# %%
decon_start_cycle = 2
decon_end_cycle = 13
decon_start_channel = 1
decon_end_channel = 4


for j in range(decon_start_cycle, decon_end_cycle+1):
    
    for i in range(decon_start_channel, decon_end_channel+1):
        
        
        decon( j, i)

# %% [markdown]
# ### 5. Extended Depth of Field

# %%
channel_name_dict = {"cyc01.tif" : ["DAPI", "Blank1a", "Blank1b", "Blank1c"],
 "cyc02.tif" : ["DAPI", "CD31", "CD8", "Empty2c"],
 "cyc03.tif" : ["DAPI", "CD20", "Ki67", "CD3e"],
 "cyc04.tif" : ["DAPI", "SMActin", "Podoplanin", "CD68"],
 "cyc05.tif" : ["DAPI", "PanCK", "CD21", "CD4"],
 "cyc06.tif" : ["DAPI", "Lyve1", "CD45RO", "CD11c"],
 "cyc07.tif" : ["DAPI", "CD35", "ECAD", "CD107a"],
 "cyc08.tif" : ["DAPI", "CD34", "CD44", "HLADR"],
 "cyc09.tif" : ["DAPI", "Empty9a", "FoxP3", "CD163"],
 "cyc10.tif" : ["DAPI", "Empty10a", "CollagenIV", "Vimentin"],
 "cyc11.tif" : ["DAPI", "Empty11a", "CD15", "CD45"],
 "cyc12.tif" : ["DAPI", "Empty12a", "CD5", "CD1c"],
 "cyc13.tif" : ["DAPI", "Blank13a", "Blank13b", "Blank13c"]}

# %%
import imagej, scyjava
ij = imagej.init('C:/Users/smith6jt/Fiji.app', add_legacy=True); print(ij.getVersion())

# %%
import imagej, scyjava
ij_mem = 40
GPU_name = "NVIDIA RTX A4500"
radius_x = 5.0
radius_y = 5.0
sigma = 20.0
edf_start_cycle = 1
edf_end_cycle = 13
edf_start_channel = 1
edf_end_channel = 4
scyjava.config.add_option(f'-Xmx{str(ij_mem)}g')
ij = imagej.init('C:/Users/smith6jt/Fiji.app', add_legacy=True)
decon_dir = stitch_dir.replace('_BaSiC_Stitched', '_Decon')
edf_dir = decon_dir.replace('_Decon', '_EDF')

macro = """
#@ File in_folder
#@ String device
#@ File out_folder
#@ String file_name
#@ Integer radius_x
#@ Integer radius_y
#@ Integer sigma

File.openSequence(in_folder);
run("CLIJ2 Macro Extensions", "cl_device=[" + device + "]");
Ext.CLIJ_clear();
image1 = "deconvolved";
Ext.CLIJ2_push(image1);
image2 = "extended_depth_of_focus_variance_projection";
radius_x = 5.0;
radius_y = 5.0;
sigma = 20.0;
Ext.CLIJ2_extendedDepthOfFocusVarianceProjection(image1, image2, radius_x, radius_y, sigma);
Ext.CLIJ2_pull(image2);
selectImage(image1);
close();
selectImage(image2);
saveAs("Tiff", out_folder + File.separator + file_name);
"""

for j in range(edf_start_cycle, edf_end_cycle+1):
    
    for i in range(edf_start_channel, edf_end_channel+1):

        edf_source = os.path.join(decon_dir, f"cyc{str(j).zfill(2)}", f"CH{str(i)}", "deconvolved")
        edf_dest = os.path.join(edf_dir, f"cyc{str(j).zfill(2)}")
        file_name = channel_name_dict.get(f"cyc{str(j).zfill(2)}.tif")[i-1]
        os.makedirs(edf_dest, exist_ok=True)

        args ={'in_folder': edf_source, "cl_device" : GPU_name, "out_folder" : edf_dest, "file_name" : file_name, "radius_x" : 5.0, "radius_y" : 5.0, "sigma" : 20.0}
        ij.py.run_macro(macro, args)

# %%
import math
import logging

logging.basicConfig(level=logging.WARN) #change to INFO for more details
# Add vips binaries to path
vipshome = 'C:/Users/smith6jt/KINTSUGI/vips-dev-8.16/bin'
os.environ['PATH'] = vipshome + ';' + os.environ['PATH']
import pyvips 
# logging.info("vips version: " + str(pyvips.version(0))+"."+str(pyvips.version(1))+"."+str(pyvips.version(2)))


idx = list(range(1, 14))
imagedir = 'C:/Users/smith6jt/KINTSUGI/data/1904_CC2B28_EDF'
outputdir = imagedir #change this to save to a different folder

dataSets = glob.glob1(imagedir, f'/cyc{str(idx).zfill(2)}/*.tif')

def eval_cb(image, progress):
        pbar_filesave.update(progress.percent - pbar_filesave.n)


for idx, dataset in enumerate(dataSets):
    str1 = dataset.split(".tif", 2)
    #print("Processing: "+ str1[0] + " " + str(idx) + " out of " + str(len(dataSets)))
    imagePrefix = str1[0]
    imageFiles = glob.glob(os.path.join(imagedir, imagePrefix+'.tif'))

    outfilename = imagePrefix + '.ome.tif'
    outfile = os.path.join(outputdir, outfilename)
    pbar_filesave = tqdm(total=100, unit="Percent", desc=outfilename, position=0, leave=True)

    images = [pyvips.Image.new_from_file(os.path.join(imagedir, filename), access="sequential") for filename in imageFiles]

    out = pyvips.Image.arrayjoin(images, across=1)
    out = out.copy()
    out.set_type(pyvips.GValue.gint_type, "page-height", images[0].height)

    # Parameters for OME metadata
    width = images[0].width
    height = images[0].height

    # Need to handle more data types
    data_type = "uint16"
    if (images[0].interpretation=="grey16"):
        data_type = "uint16"
        
    bands = int(out.height/images[0].height)
    CalibrationX = 1000/float(out.xres) #Or out.xres
    CalibrationY = 1000/float(out.yres) #Or out.yres
    CalibrationUnits = "µm" #Or out.get("resolution-unit")
    channel_names = channel_name_dict.get(f"cyc{str(idx).zfill(2)}.tif")
    
    # build minimal OME metadata
    metadata = f"""<?xml version="1.0" encoding="UTF-8"?>
    <OME xmlns="http://www.openmicroscopy.org/Schemas/OME/2016-06"
        xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"
        xsi:schemaLocation="http://www.openmicroscopy.org/Schemas/OME/2016-06 http://www.openmicroscopy.org/Schemas/OME/2016-06/ome.xsd">
        <Image ID="Image:0">
            <!-- Minimum required fields about image dimensions -->
            <Pixels DimensionOrder="XYCZT"
                    ID="Pixels:0"
                    SizeC="{bands}"
                    SizeT="1"
                    SizeX="{width}"
                    SizeY="{height}"
                    SizeZ="1"
                    Type="{data_type}"
                    PhysicalSizeX="{CalibrationX}"
                    PhysicalSizeXUnit="{CalibrationUnits}"
                    PhysicalSizeY="{CalibrationY}"
                    PhysicalSizeYUnit="{CalibrationUnits}">
                <Channel ID="Channel:0" Color="16711935" Name={channel_names[0]} SamplesPerPixel="1" />
                <Channel ID="Channel:1" Color="-1208024833" Name={channel_names[1]} SamplesPerPixel="1" />
                <Channel ID="Channel:2" Color="1828651263" Name={channel_names[2]} SamplesPerPixel="1" />
                <Channel ID="Channel:3" Color="11206655" Name={channel_names[3]} SamplesPerPixel="1" />
            </Pixels>
        </Image>
    </OME>"""

    out.set_type(pyvips.GValue.gstr_type, "image-description", metadata)
    out.set_progress(True)
    out.signal_connect('eval', eval_cb)
    
    out.write_to_file(outfile, compression='lzw', subifd=True, bigtiff=True)
