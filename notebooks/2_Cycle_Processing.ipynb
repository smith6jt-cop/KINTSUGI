# %% [markdown]
# # KINTSUGI: Knowledge Integration with New Technologies for Simplified User-Guided Image processing

# %% [markdown]
# ### In the following notebook you will use the parameters found in A_Evaluation&Testing.ipynb to correct and stitch entire datasets.

# %% [markdown]
# ## 1. Import packages.
# ### *This must be done every time the notebook is started or restarted.

# %%
from concurrent.futures import ThreadPoolExecutor
import gc
import os as os
from tqdm.notebook import tqdm
import pandas as pd
import KCorrect
from Kstitch.stitching import stitch_images
from glob import glob
from skimage.io.collection import alphanumeric_key
import numpy as np
from skimage.io import imread_collection, imsave
import stackview
import numpy as np
from itertools import chain, repeat
import subprocess
from datetime import datetime
import imagej, scyjava
import logging
import pyopencl as cl
import warnings
import platform
os_system = platform.system()
current_dateTime = datetime.now()

# %% [markdown]
# ## 2. Define directory paths.
# ### *This must be done every time the notebook is started or restarted.

# %%
base_dir = "C:\\Users\\smith6jt"

# %%
image_dir = os.path.join(base_dir, 'KINTSUGI', 'data', '1904_CC2B_raw')
stitch_dir = image_dir.replace("_raw", "_BaSiC_Stitched")
meta_dir = stitch_dir.replace("_BaSiC_Stitched", "_meta")
project_file = os.path.join(meta_dir, "project_data.txt")
print(f"Image folder is {image_dir}.")
print(f"Stitching folder is {stitch_dir}.")
print(f"Meta folder is {meta_dir}.")
# Out:
# Image folder is C:\Users\smith6jt\KINTSUGI\data\1904_CC2B_raw.
# Stitching folder is C:\Users\smith6jt\KINTSUGI\data\1904_CC2B_BaSiC_Stitched.
# Meta folder is C:\Users\smith6jt\KINTSUGI\data\1904_CC2B_meta.

# %% [markdown]
# ## 3. Stitching and Illumination Correction

# %% [markdown]
# ### 3.1 Stitching Function

# %% [markdown]
# - The following cell defines the function that is called from the apply_basic function to stitch the corrected tiles.
# - It creates a file with the stitching positions calculated from the middle z-plane images of the first channel.
# - The file is then used to stitch the rest of the images for all channels in the cycle. BECAUSE OF THIS, YOU MUST HAVE RUN THE FIRST CHANNEL OF A CYCLE TO STITCH THE OTHER CHANNELS.

# %%
def stitch(images_transformed, zplanes, dest, dest_1, channels, zplanes_n, pou, rows, cols, overlap_percentage, use_gpu):
    
    z = str(zplanes)
    ch = str(channels)
    pkl_dest = os.path.join(dest, "result_df.pkl")
    
    if zplanes == zplanes_n//2 and channels == 1:
        print(f"Start Stitching Z0{z.zfill(2)}_CH{ch}")
        if os.path.exists(pkl_dest):
            result_df = pd.read_pickle(pkl_dest)
        else:
            result_df, _ = stitch_images(images_transformed, rows, cols, initial_ncc_threshold=0.0, overlap_percentage=overlap_percentage, pou=pou, use_gpu=use_gpu)
            result_df.to_pickle(pkl_dest)
           
        
    else:
        print(f"Start Stitching Z0{z.zfill(2)}_CH{ch}")
        if os.path.exists(os.path.join(dest_1, "result_df.pkl")):
            result_df = pd.read_pickle(os.path.join(dest_1, "result_df.pkl"))

        else:
            print("Run registration channel to produce a stitching model.")

    result_df["y_pos2"] = result_df["y_pos"] - result_df["y_pos"].min()
    result_df["x_pos2"] = result_df["x_pos"] - result_df["x_pos"].min()
    
    size_y = images_transformed.shape[1]
    size_x = images_transformed.shape[2]
    
    stitched_image_size = (
        result_df["y_pos2"].max() + size_y,
        result_df["x_pos2"].max() + size_x,
    )
    stitched_image = np.zeros_like(images_transformed, shape=stitched_image_size)
    
    for i, row in result_df.iterrows():
        stitched_image[
            row["y_pos2"] : row["y_pos2"] + size_y,
            row["x_pos2"] : row["x_pos2"] + size_x,
        ] = images_transformed[i]

    result_image_file_path = os.path.join(dest,f"{z.zfill(2)}.tif") 
    imsave(result_image_file_path, stitched_image, check_contrast=False)
    
    print(f"Saved to {result_image_file_path}")

# %% [markdown]
# ### 3.2 Illumination Correction Function

# %% [markdown]
# - The following cell contains the function that will apply the illumination correction to your data.
# - Change the five variables below according to tests using the first notebook.

# %%
def apply_KCorrect(image_dir, stitch_dir, zplanes, cycles, channels, zplanes_n, pou, rows, cols, overlap_percentage, use_gpu):

    if_darkfield = True
    max_iterations = 500
    optimization_tolerance = 1e-6
    max_reweight_iterations = 25
    reweight_tolerance = 1.0e-3

    filename_pattern = f'1_000??_Z0{str(zplanes).zfill(2)}_CH{str(channels)}.tif'
    
    dest = os.path.join(stitch_dir, f"cyc{str(cycles).zfill(2)}", f"CH{str(channels)}")
    os.makedirs(dest, exist_ok=True)
    dest_1 = os.path.join(stitch_dir, f"cyc{str(cycles).zfill(2)}", "CH1")
    
    im_raw = sorted(glob(os.path.join(image_dir, f'cyc{str(cycles).zfill(3)}', filename_pattern)), key=alphanumeric_key)
    im = imread_collection(im_raw)
    im_array_init = np.asarray(im)
    dtype_max = np.iinfo(im_array_init.dtype).max
    im_array = im_array_init.astype(np.float64) / dtype_max

    if not np.all(np.isfinite(im_array)):
        raise ValueError("Input array contains inf or nan values")
    if np.any(im_array < 0):
        raise ValueError("Input array contains negative values")

    print(f"Start Illumination Correction cyc{str(cycles).zfill(2)} Z0{str(zplanes).zfill(2)}_CH{str(channels)}")
    flatfield, darkfield = KCorrect.KCorrect(im_array, if_darkfield = if_darkfield, max_iterations = max_iterations, optimization_tolerance = optimization_tolerance,  max_reweight_iterations = max_reweight_iterations, reweight_tolerance = reweight_tolerance)
    
    if np.any(np.isnan(flatfield)) or np.any(np.isnan(darkfield)):
        raise ValueError("Invalid flatfield or darkfield correction")
    if np.any(flatfield == 0):
        warnings.warn("Flatfield contains zero values which may cause division issues")
    
    corrected = np.zeros_like(im_array, dtype=np.float64)
    for i in range(len(im_array)):
        corrected[i] = ((im_array[i] - darkfield) / flatfield)
        corrected[i] = np.clip(corrected[i], 0, 1)
        
    KCorrect.validate_correction(im_array_init, corrected)
    corrected = (corrected * dtype_max).astype(np.uint16)                                       
    stitch(corrected, zplanes, dest, dest_1, channels, zplanes_n, pou, rows, cols, overlap_percentage, use_gpu)

# %% [markdown]
# ### 3.3 Running Multiple Cycle/Channel Combinations

# %% [markdown]
# - This cell runs the above two functions for all the images you define with start_cycle, end_cycle, start_channel, and end_channel.
# - Enter values for n, m, pou (determined from the first notebook), zplanes_n (number of zplanes), and overlap_percentage.
# - Enter the number of workers for the multithreading (usually determined by dataset size, available memory, and number of cores).  See https://docs.python.org/3/library/concurrent.futures.html
# - To run just one cycle or channel, simply enter the same number for both start and end.

# %%
n = 9  # Number of rows (height)
m = 7  # Number of columns (width)
start_cycle = 1
end_cycle = 13
start_channel = 1
end_channel = 4
pou = 13
zplanes_n = 17
overlap_percentage = 0.30
workers = zplanes_n-1
use_gpu = True

# Row coordinates: each row index is repeated m times
rows = list(chain.from_iterable(repeat(row, m) for row in range(n)))
# Column coordinates: snake pattern for each row, going back and forth from top left going right
cols = list(chain.from_iterable(range(m) if row % 2 == 0 else range(m - 1, -1, -1) for row in range(n)))

image_dir_list = [image_dir] * (zplanes_n-1)
stitch_dir_list = [stitch_dir] * (zplanes_n-1)
zplanes_list =[zplanes_n] * (zplanes_n-1)
pou_list = [pou] * (zplanes_n-1)
rows_list = [rows] * (zplanes_n-1)
cols_list = [cols] * (zplanes_n-1)
overlap_percentage_list = [overlap_percentage] * (zplanes_n-1)
use_gpu_list = [use_gpu] * (zplanes_n-1)


total_operations = (end_cycle - start_cycle + 1) * (end_channel - start_channel + 1)

with tqdm(total=total_operations, desc='Processing', unit='operation',
                    bar_format='{desc}: {percentage:3.0f}%|{bar}| {n_fmt}/{total_fmt} [{elapsed}<{remaining}]',
                    colour="green", position=0, leave=True) as pbar:
    for i in range(start_cycle, end_cycle+1):
        for j in range(start_channel, end_channel+1):
            pbar.set_description(f'Cycle {i} Channel {j}')
            cycles = i
            zplanes = zplanes_n//2 
            channels = display_jpeg
            apply_KCorrect(image_dir, stitch_dir, zplanes, cycles, channels, zplanes_n, pou, rows, cols, overlap_percentage, use_gpu)
            
            if __name__ ==  '__main__':
                with ThreadPoolExecutor(max_workers=workers) as executor:
                    cycles = [i] * (zplanes_n-1) 
                    zplanes =  list(range(1, zplanes_n//2))+list(range((zplanes_n//2)+1, zplanes_n+1)) 
                    channels = [j] * (zplanes_n-1)
                    executor.map(apply_KCorrect, image_dir_list, stitch_dir_list, zplanes, cycles, channels, zplanes_list, pou_list, rows_list, cols_list, overlap_percentage_list, use_gpu_list) 

            pbar.update(1)
        gc.collect()

pbar.close()

# %% [markdown]
# ## 4. Deconvolution

# %% [markdown]
# - See the first notebook for information.

# %%
def run_subprocess(command):
    
    process = subprocess.Popen(command, 
                                stdout=subprocess.PIPE, 
                                stderr=subprocess.STDOUT, 
                                shell=True, 
                                bufsize=1,
                                universal_newlines=True, 
                                text=True)
    
    while True:
        output = process.stdout.readline()
        if output == '' and process.poll() is not None:
            break
        if output:
            print(output, end='') 

    rc = process.poll()
    return rc

# %%
def decon(base_dir, stitch_dir, dec_cycle, dec_channel):

    # pixel size in xy dimension (nanometers)
    xy_vox = 377
    # pixel size in z dimension (nanometers)
    z_vox = 1500
    # Number of iterations of Lucy-Richardson algo before stopping unless stop_crit is met first
    iterations = 25
    # Microscope objective numerical aperture
    mic_NA = 0.75
    # Refractive index of tissue being imaged
    tissue_RI = 1.44
    # Opening size in millimeters of objective aperture
    slit_aper = 6.5
    # Focal length in millimeters of objective
    f_cyl = 1
    # Used to reduce noise.  Increase value for noisy images. (0-10)
    damping = 0
    # If set, the deconvolved images will be clipped by this percent for max and min values, and then scaled to full range of bit depth. (0-5)
    hist_clip = 0.01
    # Percent change between iterations to use as criteria to stop deconvolution.
    stop_criterion = 5.00
    # Percent maximum GPU or CPU memory 
    max_memory = 0.7
    # Enter 'GPU' or 'CPU'
    device = 'GPU'
    # Chunk size in bytes, or 1 for automatic chunking
    blocksize = 3072
    # The respective excitation and emission wavelength in nanometers for each channel
    wavelengths = {
        1: (358, 461),
        2: (753, 775),
        3: (560, 575),
        4: (648, 668)
    }
    
    decon_dir = stitch_dir.replace('_BaSiC_Stitched', '_Decon')
    source = os.path.join(stitch_dir, f"cyc{str(dec_cycle).zfill(2)}", f"CH{dec_channel}")
    dest = os.path.join(decon_dir, f"cyc{str(dec_cycle).zfill(2)}", f"CH{dec_channel}")
    os.makedirs(dest, exist_ok=True)

    command = [source, str(xy_vox), str(z_vox), str(iterations), str(mic_NA), str(tissue_RI), str(f_cyl), str(slit_aper), str(damping), str(hist_clip), str(stop_criterion), str(max_memory), device, str(blocksize)]

    if os_system == "Windows":

        decon_exe = os.path.join(base_dir, "KINTSUGI", "KDecon_v4.exe") 
        command.insert(0, decon_exe)
        ex_index, em_index = 7, 8

    if os_system == "Linux":

        mat_dir = "/usr/local/MATLAB/MATLAB_Runtime/R2024a/" 
        decon_exe = os.path.join(base_dir, "KINTSUGI", "for_distribution_files_only", "run_K_Decon_v4.sh")
        command.insert(0, decon_exe)
        command.insert(1, mat_dir)
        ex_index, em_index = 8, 9

    ex, em = wavelengths[dec_channel]
    command.insert(ex_index, str(ex))
    command.insert(em_index, str(em))

    run_subprocess(command)
    os.rename(os.path.join(source, 'deconvolved'), os.path.join(dest, 'deconvolved'))

# %% [markdown]
# To apply the above decon function to multiple cycles/channels, enter the start and end numbers below.

# %%
decon_start_cycle = 1
decon_end_cycle = 13

decon_start_channel = 1
decon_end_channel = 4

total_operations = (decon_end_cycle - decon_start_cycle + 1) * (decon_end_channel - decon_start_channel + 1)

with tqdm(total=total_operations, desc='Processing', unit='operation',
                    bar_format='{desc}: {percentage:3.0f}%|{bar}| {n_fmt}/{total_fmt} [{elapsed}<{remaining}]',
                    colour="green", position=0, leave=True) as pbar:
    for i in range(decon_start_cycle, decon_end_cycle+1):
        for j in range(decon_start_channel, decon_end_channel+1):
            pbar.set_description(f'Cycle {i} Channel {j}')
            decon(base_dir, stitch_dir, i, j)
            pbar.update(1)
        gc.collect()

pbar.close()
# Out:
# Processing:   0%|          | 0/52 [00:00<?]
#
# KDecon v4 - KINTSUGI
#
# CPU supported with 53.96 GB memory
# CPU: 53.96 GB available
# GPU supported with 20.24 GB memory
# GPU: NVIDIA RTX A4500
# Available devices and their memory:
# Using GPU with 14.17 GB of memory
# Image dimensions: x=9962 y=9484 z=17 blocksize3072
# Total pixels: 6.42 GB Max block size: 11.34 GB
# block_x 4 block_y 4 block_z 1
# deconvolution split into 4 x 4 x 1 blocks.
# calculating PSF...
# ok
# x 9962 y 9484 z 17
# Processing 16 blocks...
# loading block 1 from 16
# Processing block 1 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 41.7
# iteration: 3 delta: 23.7
# iteration: 4 delta: 16.3
# iteration: 5 delta: 11.9
# iteration: 6 delta: 9.11
# iteration: 7 delta: 7.4
# iteration: 8 delta: 6.35
# iteration: 9 delta: 5.7
# iteration: 10 delta: 5.29
# iteration: 11 delta: 5.03
# iteration: 12 delta: 4.84
# stop criterion reached. Finishing iterations.
# Saving block 1 from 16
# Block 1/16 complete (6.2%)
# loading block 2 from 16
# Processing block 2 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 43.2
# iteration: 3 delta: 24.8
# iteration: 4 delta: 17.4
# iteration: 5 delta: 12.8
# iteration: 6 delta: 9.9
# iteration: 7 delta: 8
# iteration: 8 delta: 6.77
# iteration: 9 delta: 5.97
# iteration: 10 delta: 5.44
# iteration: 11 delta: 5.07
# iteration: 12 delta: 4.81
# stop criterion reached. Finishing iterations.
# Saving block 2 from 16
# Block 2/16 complete (12.5%)
# loading block 3 from 16
# Processing block 3 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 42.9
# iteration: 3 delta: 25.3
# iteration: 4 delta: 17.9
# iteration: 5 delta: 13.3
# iteration: 6 delta: 10.3
# iteration: 7 delta: 8.3
# iteration: 8 delta: 7
# iteration: 9 delta: 6.15
# iteration: 10 delta: 5.58
# iteration: 11 delta: 5.18
# iteration: 12 delta: 4.9
# stop criterion reached. Finishing iterations.
# Saving block 3 from 16
# Block 3/16 complete (18.8%)
# loading block 4 from 16
# Processing block 4 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 42.5
# iteration: 3 delta: 25.9
# iteration: 4 delta: 18.5
# iteration: 5 delta: 13.8
# iteration: 6 delta: 10.6
# iteration: 7 delta: 8.53
# iteration: 8 delta: 7.16
# iteration: 9 delta: 6.27
# iteration: 10 delta: 5.68
# iteration: 11 delta: 5.28
# iteration: 12 delta: 5
# stop criterion reached. Finishing iterations.
# Saving block 4 from 16
# Block 4/16 complete (25.0%)
# loading block 5 from 16
# Processing block 5 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 42.6
# iteration: 3 delta: 23.7
# iteration: 4 delta: 16.3
# iteration: 5 delta: 12.1
# iteration: 6 delta: 9.36
# iteration: 7 delta: 7.64
# iteration: 8 delta: 6.53
# iteration: 9 delta: 5.81
# iteration: 10 delta: 5.34
# iteration: 11 delta: 5.01
# iteration: 12 delta: 4.77
# stop criterion reached. Finishing iterations.
# Saving block 5 from 16
# Block 5/16 complete (31.2%)
# loading block 6 from 16
# Processing block 6 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 43.3
# iteration: 3 delta: 24.5
# iteration: 4 delta: 17.1
# iteration: 5 delta: 12.7
# iteration: 6 delta: 9.84
# iteration: 7 delta: 7.99
# iteration: 8 delta: 6.79
# iteration: 9 delta: 5.99
# iteration: 10 delta: 5.46
# iteration: 11 delta: 5.08
# iteration: 12 delta: 4.81
# stop criterion reached. Finishing iterations.
# Saving block 6 from 16
# Block 6/16 complete (37.5%)
# loading block 7 from 16
# Processing block 7 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 43.8
# iteration: 3 delta: 24.7
# iteration: 4 delta: 17.3
# iteration: 5 delta: 12.9
# iteration: 6 delta: 10
# iteration: 7 delta: 8.13
# iteration: 8 delta: 6.89
# iteration: 9 delta: 6.06
# iteration: 10 delta: 5.49
# iteration: 11 delta: 5.09
# iteration: 12 delta: 4.79
# stop criterion reached. Finishing iterations.
# Saving block 7 from 16
# Block 7/16 complete (43.8%)
# loading block 8 from 16
# Processing block 8 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 43
# iteration: 3 delta: 24
# iteration: 4 delta: 16.6
# iteration: 5 delta: 12.3
# iteration: 6 delta: 9.51
# iteration: 7 delta: 7.74
# iteration: 8 delta: 6.6
# iteration: 9 delta: 5.87
# iteration: 10 delta: 5.37
# iteration: 11 delta: 5.04
# iteration: 12 delta: 4.79
# stop criterion reached. Finishing iterations.
# Saving block 8 from 16
# Block 8/16 complete (50.0%)
# loading block 9 from 16
# Processing block 9 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 41.8
# iteration: 3 delta: 24
# iteration: 4 delta: 16.7
# iteration: 5 delta: 12.4
# iteration: 6 delta: 9.65
# iteration: 7 delta: 7.86
# iteration: 8 delta: 6.71
# iteration: 9 delta: 5.96
# iteration: 10 delta: 5.46
# iteration: 11 delta: 5.12
# iteration: 12 delta: 4.87
# stop criterion reached. Finishing iterations.
# Saving block 9 from 16
# Block 9/16 complete (56.2%)
# loading block 10 from 16
# Processing block 10 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 42.2
# iteration: 3 delta: 25.2
# iteration: 4 delta: 18.1
# iteration: 5 delta: 13.7
# iteration: 6 delta: 10.7
# iteration: 7 delta: 8.7
# iteration: 8 delta: 7.35
# iteration: 9 delta: 6.44
# iteration: 10 delta: 5.81
# iteration: 11 delta: 5.35
# iteration: 12 delta: 5.01
# iteration: 13 delta: 4.74
# stop criterion reached. Finishing iterations.
# Saving block 10 from 16
# Block 10/16 complete (62.5%)
# loading block 11 from 16
# Processing block 11 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 43.3
# iteration: 3 delta: 24.3
# iteration: 4 delta: 17.1
# iteration: 5 delta: 12.9
# iteration: 6 delta: 10.1
# iteration: 7 delta: 8.22
# iteration: 8 delta: 6.98
# iteration: 9 delta: 6.14
# iteration: 10 delta: 5.55
# iteration: 11 delta: 5.12
# iteration: 12 delta: 4.8
# stop criterion reached. Finishing iterations.
# Saving block 11 from 16
# Block 11/16 complete (68.8%)
# loading block 12 from 16
# Processing block 12 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 41.5
# iteration: 3 delta: 23.1
# iteration: 4 delta: 15.9
# iteration: 5 delta: 11.8
# iteration: 6 delta: 9.16
# iteration: 7 delta: 7.52
# iteration: 8 delta: 6.47
# iteration: 9 delta: 5.79
# iteration: 10 delta: 5.34
# iteration: 11 delta: 5.03
# iteration: 12 delta: 4.81
# stop criterion reached. Finishing iterations.
# Saving block 12 from 16
# Block 12/16 complete (75.0%)
# loading block 13 from 16
# Processing block 13 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 40.7
# iteration: 3 delta: 22.7
# iteration: 4 delta: 15.6
# iteration: 5 delta: 11.5
# iteration: 6 delta: 8.95
# iteration: 7 delta: 7.35
# iteration: 8 delta: 6.35
# iteration: 9 delta: 5.71
# iteration: 10 delta: 5.31
# iteration: 11 delta: 5.04
# iteration: 12 delta: 4.85
# stop criterion reached. Finishing iterations.
# Saving block 13 from 16
# Block 13/16 complete (81.2%)
# loading block 14 from 16
# Processing block 14 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 41
# iteration: 3 delta: 24.4
# iteration: 4 delta: 17.3
# iteration: 5 delta: 12.9
# iteration: 6 delta: 10.1
# iteration: 7 delta: 8.2
# iteration: 8 delta: 6.97
# iteration: 9 delta: 6.16
# iteration: 10 delta: 5.62
# iteration: 11 delta: 5.24
# iteration: 12 delta: 4.96
# stop criterion reached. Finishing iterations.
# Saving block 14 from 16
# Block 14/16 complete (87.5%)
# loading block 15 from 16
# Processing block 15 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 42.2
# iteration: 3 delta: 23.7
# iteration: 4 delta: 16.6
# iteration: 5 delta: 12.4
# iteration: 6 delta: 9.74
# iteration: 7 delta: 7.97
# iteration: 8 delta: 6.8
# iteration: 9 delta: 6
# iteration: 10 delta: 5.45
# iteration: 11 delta: 5.04
# iteration: 12 delta: 4.74
# stop criterion reached. Finishing iterations.
# Saving block 15 from 16
# Block 15/16 complete (93.8%)
# loading block 16 from 16
# Processing block 16 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 42.2
# iteration: 3 delta: 23.8
# iteration: 4 delta: 16.6
# iteration: 5 delta: 12.5
# iteration: 6 delta: 9.74
# iteration: 7 delta: 7.95
# iteration: 8 delta: 6.77
# iteration: 9 delta: 5.97
# iteration: 10 delta: 5.42
# iteration: 11 delta: 5.02
# iteration: 12 delta: 4.72
# stop criterion reached. Finishing iterations.
# Saving block 16 from 16
# Block 16/16 complete (100.0%)
# calculating histogram...
# Creating results folder C:\Users\smith6jt\KINTSUGI\data\1904_CC2B_BaSiC_Stitched\cyc01\CH1\deconvolved
# mounting layer 1 from 1
# saving images...
# generating info file...
# deconvolution of: C:\Users\smith6jt\KINTSUGI\data\1904_CC2B_BaSiC_Stitched\cyc01\CH1 finished successfully
# elapsed time: 00:08
# ----------------------------------------------------------------------------------------
#
# KDecon v4 - KINTSUGI
#
# CPU supported with 53.88 GB memory
# CPU: 53.88 GB available
# GPU supported with 20.24 GB memory
# GPU: NVIDIA RTX A4500
# Available devices and their memory:
# Using GPU with 14.17 GB of memory
# Image dimensions: x=9962 y=9484 z=17 blocksize3072
# Total pixels: 6.42 GB Max block size: 11.34 GB
# block_x 4 block_y 4 block_z 1
# deconvolution split into 4 x 4 x 1 blocks.
# calculating PSF...
# ok
# x 9962 y 9484 z 17
# Processing 16 blocks...
# loading block 1 from 16
# Processing block 1 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 24.8
# iteration: 3 delta: 12.4
# iteration: 4 delta: 8.49
# iteration: 5 delta: 6.68
# iteration: 6 delta: 5.77
# iteration: 7 delta: 5.32
# iteration: 8 delta: 5.16
# iteration: 9 delta: 5.16
# iteration: 10 delta: 5.24
# iteration: 11 delta: 5.37
# iteration: 12 delta: 5.51
# iteration: 13 delta: 5.64
# iteration: 14 delta: 5.76
# iteration: 15 delta: 5.86
# iteration: 16 delta: 5.93
# iteration: 17 delta: 5.97
# iteration: 18 delta: 5.97
# iteration: 19 delta: 5.95
# iteration: 20 delta: 5.89
# iteration: 21 delta: 5.8
# iteration: 22 delta: 5.68
# iteration: 23 delta: 5.53
# iteration: 24 delta: 5.36
# iteration: 25 delta: 5.17
# Saving block 1 from 16
# Block 1/16 complete (6.2%)
# loading block 2 from 16
# Processing block 2 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 26.3
# iteration: 3 delta: 13.1
# iteration: 4 delta: 8.79
# iteration: 5 delta: 6.84
# iteration: 6 delta: 5.86
# iteration: 7 delta: 5.39
# iteration: 8 delta: 5.22
# iteration: 9 delta: 5.22
# iteration: 10 delta: 5.31
# iteration: 11 delta: 5.45
# iteration: 12 delta: 5.59
# iteration: 13 delta: 5.74
# iteration: 14 delta: 5.87
# iteration: 15 delta: 5.97
# iteration: 16 delta: 6.05
# iteration: 17 delta: 6.09
# iteration: 18 delta: 6.11
# iteration: 19 delta: 6.09
# iteration: 20 delta: 6.03
# iteration: 21 delta: 5.95
# iteration: 22 delta: 5.83
# iteration: 23 delta: 5.69
# iteration: 24 delta: 5.52
# iteration: 25 delta: 5.34
# Saving block 2 from 16
# Block 2/16 complete (12.5%)
# loading block 3 from 16
# Processing block 3 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 26.6
# iteration: 3 delta: 13.2
# iteration: 4 delta: 8.9
# iteration: 5 delta: 6.9
# iteration: 6 delta: 5.89
# iteration: 7 delta: 5.4
# iteration: 8 delta: 5.21
# iteration: 9 delta: 5.2
# iteration: 10 delta: 5.28
# iteration: 11 delta: 5.4
# iteration: 12 delta: 5.54
# iteration: 13 delta: 5.67
# iteration: 14 delta: 5.79
# iteration: 15 delta: 5.89
# iteration: 16 delta: 5.95
# iteration: 17 delta: 5.99
# iteration: 18 delta: 5.99
# iteration: 19 delta: 5.96
# iteration: 20 delta: 5.9
# iteration: 21 delta: 5.81
# iteration: 22 delta: 5.69
# iteration: 23 delta: 5.55
# iteration: 24 delta: 5.38
# iteration: 25 delta: 5.19
# Saving block 3 from 16
# Block 3/16 complete (18.8%)
# loading block 4 from 16
# Processing block 4 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 25.7
# iteration: 3 delta: 13
# iteration: 4 delta: 8.8
# iteration: 5 delta: 6.85
# iteration: 6 delta: 5.85
# iteration: 7 delta: 5.35
# iteration: 8 delta: 5.15
# iteration: 9 delta: 5.11
# iteration: 10 delta: 5.17
# iteration: 11 delta: 5.26
# iteration: 12 delta: 5.38
# iteration: 13 delta: 5.49
# iteration: 14 delta: 5.58
# iteration: 15 delta: 5.65
# iteration: 16 delta: 5.69
# iteration: 17 delta: 5.7
# iteration: 18 delta: 5.68
# iteration: 19 delta: 5.64
# iteration: 20 delta: 5.56
# iteration: 21 delta: 5.45
# iteration: 22 delta: 5.32
# iteration: 23 delta: 5.16
# iteration: 24 delta: 4.99
# stop criterion reached. Finishing iterations.
# Saving block 4 from 16
# Block 4/16 complete (25.0%)
# loading block 5 from 16
# Processing block 5 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 25.4
# iteration: 3 delta: 12.8
# iteration: 4 delta: 8.63
# iteration: 5 delta: 6.73
# iteration: 6 delta: 5.78
# iteration: 7 delta: 5.33
# iteration: 8 delta: 5.17
# iteration: 9 delta: 5.18
# iteration: 10 delta: 5.28
# iteration: 11 delta: 5.42
# iteration: 12 delta: 5.58
# iteration: 13 delta: 5.73
# iteration: 14 delta: 5.87
# iteration: 15 delta: 5.98
# iteration: 16 delta: 6.06
# iteration: 17 delta: 6.12
# iteration: 18 delta: 6.14
# iteration: 19 delta: 6.12
# iteration: 20 delta: 6.08
# iteration: 21 delta: 6
# iteration: 22 delta: 5.89
# iteration: 23 delta: 5.75
# iteration: 24 delta: 5.59
# iteration: 25 delta: 5.4
# Saving block 5 from 16
# Block 5/16 complete (31.2%)
# loading block 6 from 16
# Processing block 6 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 25.9
# iteration: 3 delta: 13
# iteration: 4 delta: 8.75
# iteration: 5 delta: 6.8
# iteration: 6 delta: 5.82
# iteration: 7 delta: 5.36
# iteration: 8 delta: 5.2
# iteration: 9 delta: 5.2
# iteration: 10 delta: 5.3
# iteration: 11 delta: 5.44
# iteration: 12 delta: 5.6
# iteration: 13 delta: 5.75
# iteration: 14 delta: 5.88
# iteration: 15 delta: 5.99
# iteration: 16 delta: 6.08
# iteration: 17 delta: 6.13
# iteration: 18 delta: 6.15
# iteration: 19 delta: 6.13
# iteration: 20 delta: 6.08
# iteration: 21 delta: 6
# iteration: 22 delta: 5.89
# iteration: 23 delta: 5.75
# iteration: 24 delta: 5.59
# iteration: 25 delta: 5.4
# Saving block 6 from 16
# Block 6/16 complete (37.5%)
# loading block 7 from 16
# Processing block 7 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 25.9
# iteration: 3 delta: 13
# iteration: 4 delta: 8.82
# iteration: 5 delta: 6.85
# iteration: 6 delta: 5.85
# iteration: 7 delta: 5.37
# iteration: 8 delta: 5.18
# iteration: 9 delta: 5.17
# iteration: 10 delta: 5.24
# iteration: 11 delta: 5.37
# iteration: 12 delta: 5.5
# iteration: 13 delta: 5.63
# iteration: 14 delta: 5.75
# iteration: 15 delta: 5.84
# iteration: 16 delta: 5.9
# iteration: 17 delta: 5.93
# iteration: 18 delta: 5.93
# iteration: 19 delta: 5.9
# iteration: 20 delta: 5.84
# iteration: 21 delta: 5.74
# iteration: 22 delta: 5.62
# iteration: 23 delta: 5.47
# iteration: 24 delta: 5.3
# iteration: 25 delta: 5.11
# Saving block 7 from 16
# Block 7/16 complete (43.8%)
# loading block 8 from 16
# Processing block 8 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 26
# iteration: 3 delta: 13.1
# iteration: 4 delta: 8.86
# iteration: 5 delta: 6.87
# iteration: 6 delta: 5.85
# iteration: 7 delta: 5.37
# iteration: 8 delta: 5.18
# iteration: 9 delta: 5.16
# iteration: 10 delta: 5.23
# iteration: 11 delta: 5.35
# iteration: 12 delta: 5.48
# iteration: 13 delta: 5.61
# iteration: 14 delta: 5.73
# iteration: 15 delta: 5.81
# iteration: 16 delta: 5.88
# iteration: 17 delta: 5.91
# iteration: 18 delta: 5.9
# iteration: 19 delta: 5.87
# iteration: 20 delta: 5.8
# iteration: 21 delta: 5.71
# iteration: 22 delta: 5.58
# iteration: 23 delta: 5.44
# iteration: 24 delta: 5.27
# iteration: 25 delta: 5.08
# Saving block 8 from 16
# Block 8/16 complete (50.0%)
# loading block 9 from 16
# Processing block 9 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 24.1
# iteration: 3 delta: 12.3
# iteration: 4 delta: 8.46
# iteration: 5 delta: 6.64
# iteration: 6 delta: 5.7
# iteration: 7 delta: 5.25
# iteration: 8 delta: 5.07
# iteration: 9 delta: 5.06
# iteration: 10 delta: 5.14
# iteration: 11 delta: 5.26
# iteration: 12 delta: 5.4
# iteration: 13 delta: 5.53
# iteration: 14 delta: 5.64
# iteration: 15 delta: 5.73
# iteration: 16 delta: 5.8
# iteration: 17 delta: 5.83
# iteration: 18 delta: 5.83
# iteration: 19 delta: 5.8
# iteration: 20 delta: 5.73
# iteration: 21 delta: 5.64
# iteration: 22 delta: 5.52
# iteration: 23 delta: 5.37
# iteration: 24 delta: 5.2
# iteration: 25 delta: 5.02
# Saving block 9 from 16
# Block 9/16 complete (56.2%)
# loading block 10 from 16
# Processing block 10 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 25.1
# iteration: 3 delta: 12.6
# iteration: 4 delta: 8.63
# iteration: 5 delta: 6.77
# iteration: 6 delta: 5.81
# iteration: 7 delta: 5.35
# iteration: 8 delta: 5.17
# iteration: 9 delta: 5.16
# iteration: 10 delta: 5.23
# iteration: 11 delta: 5.36
# iteration: 12 delta: 5.49
# iteration: 13 delta: 5.62
# iteration: 14 delta: 5.73
# iteration: 15 delta: 5.82
# iteration: 16 delta: 5.89
# iteration: 17 delta: 5.92
# iteration: 18 delta: 5.91
# iteration: 19 delta: 5.88
# iteration: 20 delta: 5.81
# iteration: 21 delta: 5.72
# iteration: 22 delta: 5.59
# iteration: 23 delta: 5.44
# iteration: 24 delta: 5.27
# iteration: 25 delta: 5.08
# Saving block 10 from 16
# Block 10/16 complete (62.5%)
# loading block 11 from 16
# Processing block 11 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 25.1
# iteration: 3 delta: 12.5
# iteration: 4 delta: 8.6
# iteration: 5 delta: 6.76
# iteration: 6 delta: 5.81
# iteration: 7 delta: 5.35
# iteration: 8 delta: 5.18
# iteration: 9 delta: 5.17
# iteration: 10 delta: 5.25
# iteration: 11 delta: 5.37
# iteration: 12 delta: 5.51
# iteration: 13 delta: 5.64
# iteration: 14 delta: 5.76
# iteration: 15 delta: 5.85
# iteration: 16 delta: 5.92
# iteration: 17 delta: 5.95
# iteration: 18 delta: 5.95
# iteration: 19 delta: 5.92
# iteration: 20 delta: 5.85
# iteration: 21 delta: 5.76
# iteration: 22 delta: 5.63
# iteration: 23 delta: 5.48
# iteration: 24 delta: 5.31
# iteration: 25 delta: 5.12
# Saving block 11 from 16
# Block 11/16 complete (68.8%)
# loading block 12 from 16
# Processing block 12 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 24.2
# iteration: 3 delta: 12.4
# iteration: 4 delta: 8.56
# iteration: 5 delta: 6.74
# iteration: 6 delta: 5.79
# iteration: 7 delta: 5.32
# iteration: 8 delta: 5.12
# iteration: 9 delta: 5.09
# iteration: 10 delta: 5.15
# iteration: 11 delta: 5.25
# iteration: 12 delta: 5.37
# iteration: 13 delta: 5.48
# iteration: 14 delta: 5.58
# iteration: 15 delta: 5.65
# iteration: 16 delta: 5.7
# iteration: 17 delta: 5.71
# iteration: 18 delta: 5.69
# iteration: 19 delta: 5.65
# iteration: 20 delta: 5.57
# iteration: 21 delta: 5.46
# iteration: 22 delta: 5.33
# iteration: 23 delta: 5.17
# iteration: 24 delta: 5
# stop criterion reached. Finishing iterations.
# Saving block 12 from 16
# Block 12/16 complete (75.0%)
# loading block 13 from 16
# Processing block 13 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 24.2
# iteration: 3 delta: 12.3
# iteration: 4 delta: 8.44
# iteration: 5 delta: 6.65
# iteration: 6 delta: 5.72
# iteration: 7 delta: 5.27
# iteration: 8 delta: 5.11
# iteration: 9 delta: 5.1
# iteration: 10 delta: 5.19
# iteration: 11 delta: 5.32
# iteration: 12 delta: 5.46
# iteration: 13 delta: 5.59
# iteration: 14 delta: 5.71
# iteration: 15 delta: 5.81
# iteration: 16 delta: 5.88
# iteration: 17 delta: 5.92
# iteration: 18 delta: 5.92
# iteration: 19 delta: 5.89
# iteration: 20 delta: 5.83
# iteration: 21 delta: 5.74
# iteration: 22 delta: 5.63
# iteration: 23 delta: 5.48
# iteration: 24 delta: 5.31
# iteration: 25 delta: 5.13
# Saving block 13 from 16
# Block 13/16 complete (81.2%)
# loading block 14 from 16
# Processing block 14 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 24.5
# iteration: 3 delta: 12.3
# iteration: 4 delta: 8.46
# iteration: 5 delta: 6.68
# iteration: 6 delta: 5.76
# iteration: 7 delta: 5.31
# iteration: 8 delta: 5.14
# iteration: 9 delta: 5.13
# iteration: 10 delta: 5.21
# iteration: 11 delta: 5.33
# iteration: 12 delta: 5.46
# iteration: 13 delta: 5.6
# iteration: 14 delta: 5.71
# iteration: 15 delta: 5.81
# iteration: 16 delta: 5.87
# iteration: 17 delta: 5.9
# iteration: 18 delta: 5.91
# iteration: 19 delta: 5.87
# iteration: 20 delta: 5.81
# iteration: 21 delta: 5.72
# iteration: 22 delta: 5.6
# iteration: 23 delta: 5.45
# iteration: 24 delta: 5.28
# iteration: 25 delta: 5.09
# Saving block 14 from 16
# Block 14/16 complete (87.5%)
# loading block 15 from 16
# Processing block 15 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 25.2
# iteration: 3 delta: 12.4
# iteration: 4 delta: 8.5
# iteration: 5 delta: 6.71
# iteration: 6 delta: 5.8
# iteration: 7 delta: 5.36
# iteration: 8 delta: 5.21
# iteration: 9 delta: 5.22
# iteration: 10 delta: 5.32
# iteration: 11 delta: 5.46
# iteration: 12 delta: 5.62
# iteration: 13 delta: 5.77
# iteration: 14 delta: 5.91
# iteration: 15 delta: 6.02
# iteration: 16 delta: 6.1
# iteration: 17 delta: 6.16
# iteration: 18 delta: 6.18
# iteration: 19 delta: 6.16
# iteration: 20 delta: 6.11
# iteration: 21 delta: 6.03
# iteration: 22 delta: 5.92
# iteration: 23 delta: 5.78
# iteration: 24 delta: 5.62
# iteration: 25 delta: 5.43
# Saving block 15 from 16
# Block 15/16 complete (93.8%)
# loading block 16 from 16
# Processing block 16 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 25.3
# iteration: 3 delta: 12.4
# iteration: 4 delta: 8.53
# iteration: 5 delta: 6.73
# iteration: 6 delta: 5.8
# iteration: 7 delta: 5.36
# iteration: 8 delta: 5.2
# iteration: 9 delta: 5.2
# iteration: 10 delta: 5.29
# iteration: 11 delta: 5.43
# iteration: 12 delta: 5.58
# iteration: 13 delta: 5.73
# iteration: 14 delta: 5.86
# iteration: 15 delta: 5.97
# iteration: 16 delta: 6.05
# iteration: 17 delta: 6.1
# iteration: 18 delta: 6.12
# iteration: 19 delta: 6.1
# iteration: 20 delta: 6.05
# iteration: 21 delta: 5.96
# iteration: 22 delta: 5.85
# iteration: 23 delta: 5.71
# iteration: 24 delta: 5.54
# iteration: 25 delta: 5.36
# Saving block 16 from 16
# Block 16/16 complete (100.0%)
# calculating histogram...
# Creating results folder C:\Users\smith6jt\KINTSUGI\data\1904_CC2B_BaSiC_Stitched\cyc01\CH2\deconvolved
# mounting layer 1 from 1
# saving images...
# generating info file...
# deconvolution of: C:\Users\smith6jt\KINTSUGI\data\1904_CC2B_BaSiC_Stitched\cyc01\CH2 finished successfully
# elapsed time: 00:16
# ----------------------------------------------------------------------------------------
#
# KDecon v4 - KINTSUGI
#
# CPU supported with 53.54 GB memory
# CPU: 53.54 GB available
# GPU supported with 20.24 GB memory
# GPU: NVIDIA RTX A4500
# Available devices and their memory:
# Using GPU with 14.17 GB of memory
# Image dimensions: x=9962 y=9484 z=17 blocksize3072
# Total pixels: 6.42 GB Max block size: 11.34 GB
# block_x 4 block_y 4 block_z 1
# deconvolution split into 4 x 4 x 1 blocks.
# calculating PSF...
# ok
# x 9962 y 9484 z 17
# Processing 16 blocks...
# loading block 1 from 16
# Processing block 1 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 24.3
# iteration: 3 delta: 12.2
# iteration: 4 delta: 8.77
# iteration: 5 delta: 7.32
# iteration: 6 delta: 6.57
# iteration: 7 delta: 6.12
# iteration: 8 delta: 5.81
# iteration: 9 delta: 5.57
# iteration: 10 delta: 5.38
# iteration: 11 delta: 5.22
# iteration: 12 delta: 5.07
# iteration: 13 delta: 4.94
# stop criterion reached. Finishing iterations.
# Saving block 1 from 16
# Block 1/16 complete (6.2%)
# loading block 2 from 16
# Processing block 2 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 24.4
# iteration: 3 delta: 12.2
# iteration: 4 delta: 8.75
# iteration: 5 delta: 7.33
# iteration: 6 delta: 6.6
# iteration: 7 delta: 6.16
# iteration: 8 delta: 5.85
# iteration: 9 delta: 5.62
# iteration: 10 delta: 5.42
# iteration: 11 delta: 5.25
# iteration: 12 delta: 5.1
# iteration: 13 delta: 4.96
# stop criterion reached. Finishing iterations.
# Saving block 2 from 16
# Block 2/16 complete (12.5%)
# loading block 3 from 16
# Processing block 3 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 24.8
# iteration: 3 delta: 12.3
# iteration: 4 delta: 8.76
# iteration: 5 delta: 7.33
# iteration: 6 delta: 6.6
# iteration: 7 delta: 6.16
# iteration: 8 delta: 5.86
# iteration: 9 delta: 5.62
# iteration: 10 delta: 5.43
# iteration: 11 delta: 5.26
# iteration: 12 delta: 5.11
# iteration: 13 delta: 4.97
# stop criterion reached. Finishing iterations.
# Saving block 3 from 16
# Block 3/16 complete (18.8%)
# loading block 4 from 16
# Processing block 4 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 25.9
# iteration: 3 delta: 12.6
# iteration: 4 delta: 8.92
# iteration: 5 delta: 7.41
# iteration: 6 delta: 6.65
# iteration: 7 delta: 6.19
# iteration: 8 delta: 5.87
# iteration: 9 delta: 5.63
# iteration: 10 delta: 5.43
# iteration: 11 delta: 5.27
# iteration: 12 delta: 5.12
# iteration: 13 delta: 4.98
# stop criterion reached. Finishing iterations.
# Saving block 4 from 16
# Block 4/16 complete (25.0%)
# loading block 5 from 16
# Processing block 5 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 23.8
# iteration: 3 delta: 12
# iteration: 4 delta: 8.66
# iteration: 5 delta: 7.28
# iteration: 6 delta: 6.58
# iteration: 7 delta: 6.15
# iteration: 8 delta: 5.85
# iteration: 9 delta: 5.62
# iteration: 10 delta: 5.42
# iteration: 11 delta: 5.25
# iteration: 12 delta: 5.1
# iteration: 13 delta: 4.96
# stop criterion reached. Finishing iterations.
# Saving block 5 from 16
# Block 5/16 complete (31.2%)
# loading block 6 from 16
# Processing block 6 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 24.3
# iteration: 3 delta: 12.2
# iteration: 4 delta: 8.72
# iteration: 5 delta: 7.32
# iteration: 6 delta: 6.61
# iteration: 7 delta: 6.18
# iteration: 8 delta: 5.87
# iteration: 9 delta: 5.64
# iteration: 10 delta: 5.44
# iteration: 11 delta: 5.27
# iteration: 12 delta: 5.11
# iteration: 13 delta: 4.97
# stop criterion reached. Finishing iterations.
# Saving block 6 from 16
# Block 6/16 complete (37.5%)
# loading block 7 from 16
# Processing block 7 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 26.5
# iteration: 3 delta: 12.9
# iteration: 4 delta: 9.02
# iteration: 5 delta: 7.48
# iteration: 6 delta: 6.7
# iteration: 7 delta: 6.24
# iteration: 8 delta: 5.92
# iteration: 9 delta: 5.67
# iteration: 10 delta: 5.46
# iteration: 11 delta: 5.29
# iteration: 12 delta: 5.13
# iteration: 13 delta: 4.98
# stop criterion reached. Finishing iterations.
# Saving block 7 from 16
# Block 7/16 complete (43.8%)
# loading block 8 from 16
# Processing block 8 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 26
# iteration: 3 delta: 12.7
# iteration: 4 delta: 8.94
# iteration: 5 delta: 7.42
# iteration: 6 delta: 6.67
# iteration: 7 delta: 6.21
# iteration: 8 delta: 5.89
# iteration: 9 delta: 5.65
# iteration: 10 delta: 5.45
# iteration: 11 delta: 5.27
# iteration: 12 delta: 5.12
# iteration: 13 delta: 4.98
# stop criterion reached. Finishing iterations.
# Saving block 8 from 16
# Block 8/16 complete (50.0%)
# loading block 9 from 16
# Processing block 9 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 24.6
# iteration: 3 delta: 12.3
# iteration: 4 delta: 8.68
# iteration: 5 delta: 7.24
# iteration: 6 delta: 6.52
# iteration: 7 delta: 6.1
# iteration: 8 delta: 5.81
# iteration: 9 delta: 5.58
# iteration: 10 delta: 5.4
# iteration: 11 delta: 5.24
# iteration: 12 delta: 5.1
# iteration: 13 delta: 4.97
# stop criterion reached. Finishing iterations.
# Saving block 9 from 16
# Block 9/16 complete (56.2%)
# loading block 10 from 16
# Processing block 10 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 26
# iteration: 3 delta: 12.8
# iteration: 4 delta: 8.93
# iteration: 5 delta: 7.38
# iteration: 6 delta: 6.62
# iteration: 7 delta: 6.17
# iteration: 8 delta: 5.86
# iteration: 9 delta: 5.63
# iteration: 10 delta: 5.43
# iteration: 11 delta: 5.26
# iteration: 12 delta: 5.1
# iteration: 13 delta: 4.96
# stop criterion reached. Finishing iterations.
# Saving block 10 from 16
# Block 10/16 complete (62.5%)
# loading block 11 from 16
# Processing block 11 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 26.4
# iteration: 3 delta: 13
# iteration: 4 delta: 9.02
# iteration: 5 delta: 7.43
# iteration: 6 delta: 6.65
# iteration: 7 delta: 6.2
# iteration: 8 delta: 5.89
# iteration: 9 delta: 5.64
# iteration: 10 delta: 5.44
# iteration: 11 delta: 5.26
# iteration: 12 delta: 5.1
# iteration: 13 delta: 4.96
# stop criterion reached. Finishing iterations.
# Saving block 11 from 16
# Block 11/16 complete (68.8%)
# loading block 12 from 16
# Processing block 12 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 27.7
# iteration: 3 delta: 13.4
# iteration: 4 delta: 9.19
# iteration: 5 delta: 7.5
# iteration: 6 delta: 6.68
# iteration: 7 delta: 6.2
# iteration: 8 delta: 5.88
# iteration: 9 delta: 5.63
# iteration: 10 delta: 5.43
# iteration: 11 delta: 5.26
# iteration: 12 delta: 5.1
# iteration: 13 delta: 4.97
# stop criterion reached. Finishing iterations.
# Saving block 12 from 16
# Block 12/16 complete (75.0%)
# loading block 13 from 16
# Processing block 13 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 25.1
# iteration: 3 delta: 12.6
# iteration: 4 delta: 8.79
# iteration: 5 delta: 7.28
# iteration: 6 delta: 6.53
# iteration: 7 delta: 6.1
# iteration: 8 delta: 5.8
# iteration: 9 delta: 5.57
# iteration: 10 delta: 5.38
# iteration: 11 delta: 5.22
# iteration: 12 delta: 5.08
# iteration: 13 delta: 4.94
# stop criterion reached. Finishing iterations.
# Saving block 13 from 16
# Block 13/16 complete (81.2%)
# loading block 14 from 16
# Processing block 14 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 25.7
# iteration: 3 delta: 12.9
# iteration: 4 delta: 8.93
# iteration: 5 delta: 7.33
# iteration: 6 delta: 6.55
# iteration: 7 delta: 6.1
# iteration: 8 delta: 5.79
# iteration: 9 delta: 5.56
# iteration: 10 delta: 5.37
# iteration: 11 delta: 5.2
# iteration: 12 delta: 5.06
# iteration: 13 delta: 4.92
# stop criterion reached. Finishing iterations.
# Saving block 14 from 16
# Block 14/16 complete (87.5%)
# loading block 15 from 16
# Processing block 15 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 24.7
# iteration: 3 delta: 12.6
# iteration: 4 delta: 8.82
# iteration: 5 delta: 7.27
# iteration: 6 delta: 6.52
# iteration: 7 delta: 6.09
# iteration: 8 delta: 5.79
# iteration: 9 delta: 5.57
# iteration: 10 delta: 5.38
# iteration: 11 delta: 5.21
# iteration: 12 delta: 5.06
# iteration: 13 delta: 4.92
# stop criterion reached. Finishing iterations.
# Saving block 15 from 16
# Block 15/16 complete (93.8%)
# loading block 16 from 16
# Processing block 16 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 24.8
# iteration: 3 delta: 12.6
# iteration: 4 delta: 8.83
# iteration: 5 delta: 7.28
# iteration: 6 delta: 6.52
# iteration: 7 delta: 6.08
# iteration: 8 delta: 5.79
# iteration: 9 delta: 5.56
# iteration: 10 delta: 5.37
# iteration: 11 delta: 5.21
# iteration: 12 delta: 5.06
# iteration: 13 delta: 4.93
# stop criterion reached. Finishing iterations.
# Saving block 16 from 16
# Block 16/16 complete (100.0%)
# calculating histogram...
# mounting layer 1 from 1
# saving images...
# generating info file...
# deconvolution of: C:\Users\smith6jt\KINTSUGI\data\1904_CC2B_BaSiC_Stitched\cyc01\CH3 finished successfully
# elapsed time: 00:10
# ----------------------------------------------------------------------------------------
#
# KDecon v4 - KINTSUGI
#
# CPU supported with 53.28 GB memory
# CPU: 53.28 GB available
# GPU supported with 20.24 GB memory
# GPU: NVIDIA RTX A4500
# Available devices and their memory:
# Using GPU with 14.17 GB of memory
# Image dimensions: x=9962 y=9484 z=17 blocksize3072
# Total pixels: 6.42 GB Max block size: 11.34 GB
# block_x 4 block_y 4 block_z 1
# deconvolution split into 4 x 4 x 1 blocks.
# calculating PSF...
# ok
# x 9962 y 9484 z 17
# Processing 16 blocks...
# loading block 1 from 16
# Processing block 1 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 32.6
# iteration: 3 delta: 14.4
# iteration: 4 delta: 8.56
# iteration: 5 delta: 6.29
# iteration: 6 delta: 5.34
# iteration: 7 delta: 4.95
# stop criterion reached. Finishing iterations.
# Saving block 1 from 16
# Block 1/16 complete (6.2%)
# loading block 2 from 16
# Processing block 2 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 33.3
# iteration: 3 delta: 14.8
# iteration: 4 delta: 8.75
# iteration: 5 delta: 6.36
# iteration: 6 delta: 5.37
# iteration: 7 delta: 4.96
# stop criterion reached. Finishing iterations.
# Saving block 2 from 16
# Block 2/16 complete (12.5%)
# loading block 3 from 16
# Processing block 3 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 33.8
# iteration: 3 delta: 15.1
# iteration: 4 delta: 8.86
# iteration: 5 delta: 6.4
# iteration: 6 delta: 5.38
# iteration: 7 delta: 4.97
# stop criterion reached. Finishing iterations.
# Saving block 3 from 16
# Block 3/16 complete (18.8%)
# loading block 4 from 16
# Processing block 4 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 35.3
# iteration: 3 delta: 15.9
# iteration: 4 delta: 9.26
# iteration: 5 delta: 6.62
# iteration: 6 delta: 5.51
# iteration: 7 delta: 5.06
# iteration: 8 delta: 4.89
# stop criterion reached. Finishing iterations.
# Saving block 4 from 16
# Block 4/16 complete (25.0%)
# loading block 5 from 16
# Processing block 5 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 32
# iteration: 3 delta: 14.2
# iteration: 4 delta: 8.44
# iteration: 5 delta: 6.17
# iteration: 6 delta: 5.24
# iteration: 7 delta: 4.87
# stop criterion reached. Finishing iterations.
# Saving block 5 from 16
# Block 5/16 complete (31.2%)
# loading block 6 from 16
# Processing block 6 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 32.3
# iteration: 3 delta: 14.4
# iteration: 4 delta: 8.52
# iteration: 5 delta: 6.2
# iteration: 6 delta: 5.25
# iteration: 7 delta: 4.87
# stop criterion reached. Finishing iterations.
# Saving block 6 from 16
# Block 6/16 complete (37.5%)
# loading block 7 from 16
# Processing block 7 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 33.9
# iteration: 3 delta: 15.2
# iteration: 4 delta: 8.92
# iteration: 5 delta: 6.42
# iteration: 6 delta: 5.38
# iteration: 7 delta: 4.97
# stop criterion reached. Finishing iterations.
# Saving block 7 from 16
# Block 7/16 complete (43.8%)
# loading block 8 from 16
# Processing block 8 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 34
# iteration: 3 delta: 15.3
# iteration: 4 delta: 8.96
# iteration: 5 delta: 6.44
# iteration: 6 delta: 5.39
# iteration: 7 delta: 4.97
# stop criterion reached. Finishing iterations.
# Saving block 8 from 16
# Block 8/16 complete (50.0%)
# loading block 9 from 16
# Processing block 9 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 32.3
# iteration: 3 delta: 14.2
# iteration: 4 delta: 8.43
# iteration: 5 delta: 6.17
# iteration: 6 delta: 5.24
# iteration: 7 delta: 4.87
# stop criterion reached. Finishing iterations.
# Saving block 9 from 16
# Block 9/16 complete (56.2%)
# loading block 10 from 16
# Processing block 10 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 32.8
# iteration: 3 delta: 14.4
# iteration: 4 delta: 8.59
# iteration: 5 delta: 6.32
# iteration: 6 delta: 5.37
# iteration: 7 delta: 4.98
# stop criterion reached. Finishing iterations.
# Saving block 10 from 16
# Block 10/16 complete (62.5%)
# loading block 11 from 16
# Processing block 11 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 32.4
# iteration: 3 delta: 14.2
# iteration: 4 delta: 8.52
# iteration: 5 delta: 6.29
# iteration: 6 delta: 5.35
# iteration: 7 delta: 4.98
# stop criterion reached. Finishing iterations.
# Saving block 11 from 16
# Block 11/16 complete (68.8%)
# loading block 12 from 16
# Processing block 12 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 33.2
# iteration: 3 delta: 14.6
# iteration: 4 delta: 8.76
# iteration: 5 delta: 6.41
# iteration: 6 delta: 5.42
# iteration: 7 delta: 5.01
# iteration: 8 delta: 4.87
# stop criterion reached. Finishing iterations.
# Saving block 12 from 16
# Block 12/16 complete (75.0%)
# loading block 13 from 16
# Processing block 13 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 32
# iteration: 3 delta: 14
# iteration: 4 delta: 8.43
# iteration: 5 delta: 6.22
# iteration: 6 delta: 5.29
# iteration: 7 delta: 4.92
# stop criterion reached. Finishing iterations.
# Saving block 13 from 16
# Block 13/16 complete (81.2%)
# loading block 14 from 16
# Processing block 14 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 32.1
# iteration: 3 delta: 13.9
# iteration: 4 delta: 8.45
# iteration: 5 delta: 6.29
# iteration: 6 delta: 5.36
# iteration: 7 delta: 4.98
# stop criterion reached. Finishing iterations.
# Saving block 14 from 16
# Block 14/16 complete (87.5%)
# loading block 15 from 16
# Processing block 15 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 30.9
# iteration: 3 delta: 13.4
# iteration: 4 delta: 8.18
# iteration: 5 delta: 6.14
# iteration: 6 delta: 5.27
# iteration: 7 delta: 4.92
# stop criterion reached. Finishing iterations.
# Saving block 15 from 16
# Block 15/16 complete (93.8%)
# loading block 16 from 16
# Processing block 16 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 31.2
# iteration: 3 delta: 13.5
# iteration: 4 delta: 8.26
# iteration: 5 delta: 6.19
# iteration: 6 delta: 5.3
# iteration: 7 delta: 4.94
# stop criterion reached. Finishing iterations.
# Saving block 16 from 16
# Block 16/16 complete (100.0%)
# calculating histogram...
# Creating results folder C:\Users\smith6jt\KINTSUGI\data\1904_CC2B_BaSiC_Stitched\cyc01\CH4\deconvolved
# mounting layer 1 from 1
# saving images...
# generating info file...
# deconvolution of: C:\Users\smith6jt\KINTSUGI\data\1904_CC2B_BaSiC_Stitched\cyc01\CH4 finished successfully
# elapsed time: 00:07
# ----------------------------------------------------------------------------------------
#
# KDecon v4 - KINTSUGI
#
# CPU supported with 53.26 GB memory
# CPU: 53.26 GB available
# GPU supported with 20.24 GB memory
# GPU: NVIDIA RTX A4500
# Available devices and their memory:
# Using GPU with 14.17 GB of memory
# Image dimensions: x=9964 y=9486 z=17 blocksize3072
# Total pixels: 6.43 GB Max block size: 11.34 GB
# block_x 4 block_y 4 block_z 1
# deconvolution split into 4 x 4 x 1 blocks.
# calculating PSF...
# ok
# x 9964 y 9486 z 17
# Processing 16 blocks...
# loading block 1 from 16
# Processing block 1 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 41.4
# iteration: 3 delta: 23.6
# iteration: 4 delta: 16.2
# iteration: 5 delta: 11.8
# iteration: 6 delta: 9.09
# iteration: 7 delta: 7.41
# iteration: 8 delta: 6.37
# iteration: 9 delta: 5.72
# iteration: 10 delta: 5.31
# iteration: 11 delta: 5.03
# iteration: 12 delta: 4.85
# stop criterion reached. Finishing iterations.
# Saving block 1 from 16
# Block 1/16 complete (6.2%)
# loading block 2 from 16
# Processing block 2 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 43
# iteration: 3 delta: 24.8
# iteration: 4 delta: 17.4
# iteration: 5 delta: 12.9
# iteration: 6 delta: 9.95
# iteration: 7 delta: 8.05
# iteration: 8 delta: 6.82
# iteration: 9 delta: 6.02
# iteration: 10 delta: 5.48
# iteration: 11 delta: 5.11
# iteration: 12 delta: 4.84
# stop criterion reached. Finishing iterations.
# Saving block 2 from 16
# Block 2/16 complete (12.5%)
# loading block 3 from 16
# Processing block 3 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 42.8
# iteration: 3 delta: 25.2
# iteration: 4 delta: 17.8
# iteration: 5 delta: 13.2
# iteration: 6 delta: 10.2
# iteration: 7 delta: 8.17
# iteration: 8 delta: 6.89
# iteration: 9 delta: 6.05
# iteration: 10 delta: 5.49
# iteration: 11 delta: 5.11
# iteration: 12 delta: 4.83
# stop criterion reached. Finishing iterations.
# Saving block 3 from 16
# Block 3/16 complete (18.8%)
# loading block 4 from 16
# Processing block 4 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 42.1
# iteration: 3 delta: 25.5
# iteration: 4 delta: 18.2
# iteration: 5 delta: 13.5
# iteration: 6 delta: 10.4
# iteration: 7 delta: 8.39
# iteration: 8 delta: 7.06
# iteration: 9 delta: 6.2
# iteration: 10 delta: 5.62
# iteration: 11 delta: 5.23
# iteration: 12 delta: 4.95
# stop criterion reached. Finishing iterations.
# Saving block 4 from 16
# Block 4/16 complete (25.0%)
# loading block 5 from 16
# Processing block 5 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 42.6
# iteration: 3 delta: 23.7
# iteration: 4 delta: 16.4
# iteration: 5 delta: 12.1
# iteration: 6 delta: 9.35
# iteration: 7 delta: 7.62
# iteration: 8 delta: 6.52
# iteration: 9 delta: 5.8
# iteration: 10 delta: 5.33
# iteration: 11 delta: 5
# stop criterion reached. Finishing iterations.
# Saving block 5 from 16
# Block 5/16 complete (31.2%)
# loading block 6 from 16
# Processing block 6 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 42.7
# iteration: 3 delta: 24.2
# iteration: 4 delta: 16.9
# iteration: 5 delta: 12.6
# iteration: 6 delta: 9.76
# iteration: 7 delta: 7.93
# iteration: 8 delta: 6.75
# iteration: 9 delta: 5.96
# iteration: 10 delta: 5.43
# iteration: 11 delta: 5.05
# iteration: 12 delta: 4.78
# stop criterion reached. Finishing iterations.
# Saving block 6 from 16
# Block 6/16 complete (37.5%)
# loading block 7 from 16
# Processing block 7 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 43.2
# iteration: 3 delta: 24.4
# iteration: 4 delta: 17
# iteration: 5 delta: 12.7
# iteration: 6 delta: 9.82
# iteration: 7 delta: 7.97
# iteration: 8 delta: 6.76
# iteration: 9 delta: 5.95
# iteration: 10 delta: 5.4
# iteration: 11 delta: 5.01
# iteration: 12 delta: 4.72
# stop criterion reached. Finishing iterations.
# Saving block 7 from 16
# Block 7/16 complete (43.8%)
# loading block 8 from 16
# Processing block 8 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 42.3
# iteration: 3 delta: 23.8
# iteration: 4 delta: 16.4
# iteration: 5 delta: 12.2
# iteration: 6 delta: 9.42
# iteration: 7 delta: 7.68
# iteration: 8 delta: 6.56
# iteration: 9 delta: 5.84
# iteration: 10 delta: 5.35
# iteration: 11 delta: 5.01
# iteration: 12 delta: 4.76
# stop criterion reached. Finishing iterations.
# Saving block 8 from 16
# Block 8/16 complete (50.0%)
# loading block 9 from 16
# Processing block 9 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 41.6
# iteration: 3 delta: 23.9
# iteration: 4 delta: 16.7
# iteration: 5 delta: 12.4
# iteration: 6 delta: 9.59
# iteration: 7 delta: 7.8
# iteration: 8 delta: 6.65
# iteration: 9 delta: 5.9
# iteration: 10 delta: 5.4
# iteration: 11 delta: 5.06
# iteration: 12 delta: 4.81
# stop criterion reached. Finishing iterations.
# Saving block 9 from 16
# Block 9/16 complete (56.2%)
# loading block 10 from 16
# Processing block 10 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 41.6
# iteration: 3 delta: 24.8
# iteration: 4 delta: 17.7
# iteration: 5 delta: 13.3
# iteration: 6 delta: 10.3
# iteration: 7 delta: 8.37
# iteration: 8 delta: 7.07
# iteration: 9 delta: 6.2
# iteration: 10 delta: 5.61
# iteration: 11 delta: 5.18
# iteration: 12 delta: 4.86
# stop criterion reached. Finishing iterations.
# Saving block 10 from 16
# Block 10/16 complete (62.5%)
# loading block 11 from 16
# Processing block 11 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 42.5
# iteration: 3 delta: 23.9
# iteration: 4 delta: 16.8
# iteration: 5 delta: 12.5
# iteration: 6 delta: 9.79
# iteration: 7 delta: 7.98
# iteration: 8 delta: 6.77
# iteration: 9 delta: 5.96
# iteration: 10 delta: 5.39
# iteration: 11 delta: 4.98
# stop criterion reached. Finishing iterations.
# Saving block 11 from 16
# Block 11/16 complete (68.8%)
# loading block 12 from 16
# Processing block 12 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 40.7
# iteration: 3 delta: 22.6
# iteration: 4 delta: 15.6
# iteration: 5 delta: 11.5
# iteration: 6 delta: 8.94
# iteration: 7 delta: 7.33
# iteration: 8 delta: 6.32
# iteration: 9 delta: 5.66
# iteration: 10 delta: 5.23
# iteration: 11 delta: 4.93
# stop criterion reached. Finishing iterations.
# Saving block 12 from 16
# Block 12/16 complete (75.0%)
# loading block 13 from 16
# Processing block 13 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 40.2
# iteration: 3 delta: 22.4
# iteration: 4 delta: 15.3
# iteration: 5 delta: 11.2
# iteration: 6 delta: 8.66
# iteration: 7 delta: 7.1
# iteration: 8 delta: 6.14
# iteration: 9 delta: 5.55
# iteration: 10 delta: 5.17
# iteration: 11 delta: 4.93
# stop criterion reached. Finishing iterations.
# Saving block 13 from 16
# Block 13/16 complete (81.2%)
# loading block 14 from 16
# Processing block 14 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 40.5
# iteration: 3 delta: 23.8
# iteration: 4 delta: 16.7
# iteration: 5 delta: 12.4
# iteration: 6 delta: 9.61
# iteration: 7 delta: 7.8
# iteration: 8 delta: 6.63
# iteration: 9 delta: 5.88
# iteration: 10 delta: 5.38
# iteration: 11 delta: 5.03
# iteration: 12 delta: 4.78
# stop criterion reached. Finishing iterations.
# Saving block 14 from 16
# Block 14/16 complete (87.5%)
# loading block 15 from 16
# Processing block 15 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 41
# iteration: 3 delta: 22.7
# iteration: 4 delta: 15.7
# iteration: 5 delta: 11.7
# iteration: 6 delta: 9.1
# iteration: 7 delta: 7.46
# iteration: 8 delta: 6.39
# iteration: 9 delta: 5.69
# iteration: 10 delta: 5.21
# iteration: 11 delta: 4.88
# stop criterion reached. Finishing iterations.
# Saving block 15 from 16
# Block 15/16 complete (93.8%)
# loading block 16 from 16
# Processing block 16 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 41.2
# iteration: 3 delta: 23.1
# iteration: 4 delta: 16.1
# iteration: 5 delta: 12
# iteration: 6 delta: 9.34
# iteration: 7 delta: 7.63
# iteration: 8 delta: 6.51
# iteration: 9 delta: 5.77
# iteration: 10 delta: 5.25
# iteration: 11 delta: 4.89
# stop criterion reached. Finishing iterations.
# Saving block 16 from 16
# Block 16/16 complete (100.0%)
# calculating histogram...
# Creating results folder C:\Users\smith6jt\KINTSUGI\data\1904_CC2B_BaSiC_Stitched\cyc02\CH1\deconvolved
# mounting layer 1 from 1
# saving images...
# generating info file...
# deconvolution of: C:\Users\smith6jt\KINTSUGI\data\1904_CC2B_BaSiC_Stitched\cyc02\CH1 finished successfully
# elapsed time: 00:08
# ----------------------------------------------------------------------------------------
#
# KDecon v4 - KINTSUGI
#
# CPU supported with 49.80 GB memory
# CPU: 49.80 GB available
# GPU supported with 20.24 GB memory
# GPU: NVIDIA RTX A4500
# Available devices and their memory:
# Using GPU with 14.17 GB of memory
# Image dimensions: x=9964 y=9486 z=17 blocksize3072
# Total pixels: 6.43 GB Max block size: 11.34 GB
# block_x 4 block_y 4 block_z 1
# deconvolution split into 4 x 4 x 1 blocks.
# calculating PSF...
# ok
# x 9964 y 9486 z 17
# Processing 16 blocks...
# loading block 1 from 16
# Processing block 1 from 16
# iteration: 1 delta: 0
# iteration: 2 delta: 28.7
# iteration: 3 delta: 14.5
# iteration: 4 delta: 9.7
# iteration: 5 delta: 7.46
# iteration: 6 delta: 6.3
# iteration: 7 delta: 5.7
# iteration: 8 delta: 5.43
# iteration: 9 delta: 5.35
# iteration: 10 delta: 5.39
# iteration: 11 delta: 5.48
# iteration: 12 delta: 5.6
# iteration: 13 delta: 5.72
# iteration: 14 delta: 5.83
# iteration: 15 delta: 5.93
# iteration: 16 delta: 6
# iteration: 17 delta: 6.05
# iteration: 18 delta: 6.07
# iteration: 19 delta: 6.05
# iteration: 20 delta: 6.01
# iteration: 21 delta: 5.94
# iteration: 22 delta: 5.83
# iteration: 23 delta: 5.71
# iteration: 24 delta: 5.55
# iteration: 25 delta: 5.38
# Saving block 1 from 16
# Block 1/16 complete (6.2%)
# loading block 2 from 16

# %% [markdown]
# ## 5. FIJI Clij2 plugin - EDF

# %% [markdown]
# See the previous notebook for information.

# %%
fiji_dir = os.path.join(base_dir, "Fiji.app")
javahome = os.path.join(base_dir, "KINTSUGI", "jdk-21_windows-x64_bin", "jdk-21.0.5", "bin")
os.environ['PATH'] = javahome + os.pathsep + os.environ['PATH']
mavenhome = os.path.join(base_dir, 'KINTSUGI','apache-maven-3.9.9-bin','apache-maven-3.9.9', 'bin')
os.environ['PATH'] = mavenhome + os.pathsep + os.environ['PATH']

ij_mem = 50
scyjava.config.add_option(f'-Xmx{str(ij_mem)}g')
ij = imagej.init(fiji_dir)

# %%
platforms = cl.get_platforms()
for platform in platforms:
    print(f"Platform: {platform.name}")
    devices = platform.get_devices()
    for device in devices:
        print(f"  Device: {device.name} - Type: {cl.device_type.to_string(device.type)}")

# Select a CPU device (assuming the first CPU device found)
cpu_device = None
for platform in platforms:
    devices = platform.get_devices()
    for device in devices:
        if device.type == cl.device_type.CPU:
            cpu_device = device
            break
    if cpu_device:
        break
# Out:
# Platform: Intel(R) OpenCL Graphics
#   Device: Intel(R) UHD Graphics 770 - Type: ALL | GPU
# Platform: NVIDIA CUDA
#   Device: NVIDIA RTX A4500 - Type: ALL | GPU
# Platform: Intel(R) OpenCL
#   Device: 13th Gen Intel(R) Core(TM) i9-13900 - Type: ALL | CPU

# %%
channel_name_dict = {"cyc01.tif" : ["DAPI", "Blank1a", "Blank1b", "Blank1c"],
 "cyc02.tif" : ["DAPI", "CD31", "CD8", "Empty2c"],
 "cyc03.tif" : ["DAPI", "CD20", "Ki67", "CD3e"],
 "cyc04.tif" : ["DAPI", "SMActin", "Podoplanin", "CD68"],
 "cyc05.tif" : ["DAPI", "PanCK", "CD21", "CD4"],
 "cyc06.tif" : ["DAPI", "Lyve1", "CD45RO", "CD11c"],
 "cyc07.tif" : ["DAPI", "CD35", "ECAD", "CD107a"],
 "cyc08.tif" : ["DAPI", "CD34", "CD44", "HLADR"],
 "cyc09.tif" : ["DAPI", "Empty9a", "FoxP3", "CD163"],
 "cyc10.tif" : ["DAPI", "Empty10a", "CollagenIV", "Vimentin"],
 "cyc11.tif" : ["DAPI", "Empty11a", "CD15", "CD45"],
 "cyc12.tif" : ["DAPI", "Empty12a", "CD5", "CD1c"],
 "cyc13.tif" : ["DAPI", "Blank13a", "Blank13b", "Blank13c"]}

# %%
edf_start_cycle = 1
edf_end_cycle = 13

edf_start_channel = 1
edf_end_channel = 4

decon_dir = stitch_dir.replace('_BaSiC_Stitched', '_Decon')
edf_dir = decon_dir.replace('_Decon', '_EDF')

# %%
device = "NVIDIA RTX A4500"

radius_x = 5
radius_y = 5
sigma = 20.0
xSplit = 3
ySplit = 3
GPU = True

macro = """
#@ File in_folder
#@ String device
#@ File out_folder
#@ String file_name
#@ Integer radius_x
#@ Integer radius_y
#@ Float sigma
#@ Integer xTiles
#@ Integer yTiles
#@ Boolean GPU

run("CLIJ2 Macro Extensions", "cl_device=[" + device + "] automatic_output_naming=false");
Ext.CLIJ2_clear();
//setBatchMode(true);

File.openSequence(in_folder);
input = getTitle();
Stack.getDimensions(width, height, channels, slices, frames);

if (GPU == true) {
	output = "output";
	newImage(output, "16-bit black", width, height, 1);
    } else {
    Ext.CLIJ2_push(input);
	Ext.CLIJ2_create2D(output, width, height, 16);
    }

numTilesZ = 1;
numTilesX = xTiles;
numTilesY = yTiles;

tileDepth = round((slices/numTilesZ));
tileWidth = round((width/numTilesX));
tileHeight = round((height/numTilesY));

for (x = 0; x < numTilesX; x++) {
	showProgress(x+1, numTilesX);
	for (y = 0; y < numTilesY; y++) {
		for (z = 0; z < numTilesZ; z++) {

			Ext.CLIJ2_pushTile(input, x, y, z, tileWidth, tileHeight, tileDepth, 0, 0, 0);		
			Ext.CLIJ2_extendedDepthOfFocusVarianceProjection(input, output, radius_x, radius_y, sigma);
            Ext.CLIJ2_release(input);
            if (GPU == true) {
				Ext.CLIJ2_pullTile(output, x, y, z, tileWidth, tileHeight, 1, 0, 0, 0);
				Ext.CLIJ2_release(output);
			}            
		}
	}
}

if (GPU == false) {
	Ext.CLIJ2_pull(output);
    Ext.CLIJ2_release(output);
}

selectImage(output);
saveAs("Tiff", out_folder + File.separator + file_name);

Ext.CLIJ2_clear();
run("Close All");
"""


total_operations = (edf_end_cycle - edf_start_cycle + 1) * (edf_end_channel - edf_start_channel + 1)

with tqdm(total=total_operations, desc='Processing', unit='operation',
                    bar_format='{desc}: {percentage:3.0f}%|{bar}| {n_fmt}/{total_fmt} [{elapsed}<{remaining}]',
                    colour="green", position=0, leave=True) as pbar:
    for i in range(edf_start_cycle, edf_end_cycle+1):
        
        for j in range(edf_start_channel, edf_end_channel+1):

            pbar.set_description(f'Cycle {i} Channel {j}')
            
            edf_source = os.path.join(decon_dir, f"cyc{str(i).zfill(2)}", f"CH{str(j)}", "deconvolved")
            edf_dest = os.path.join(edf_dir, f"cyc{str(i).zfill(2)}")
            file_name = channel_name_dict.get(f"cyc{str(i).zfill(2)}.tif")[j-1]
            os.makedirs(edf_dest, exist_ok=True)

            args = {'in_folder': edf_source, "device" : device, "out_folder" : edf_dest, "file_name" : file_name, "radius_x" : radius_x, "radius_y" : radius_y, "sigma" : sigma, "xTiles" : xSplit, "yTiles" : ySplit, "GPU" : GPU}

            ij.py.run_macro(macro, args)

            pbar.update(1)
        gc.collect()

pbar.close()
# Out:
# Processing:   0%|          | 0/52 [00:00<?]
# Operating in headless mode - the original ImageJ will have limited functionality.

# %% [markdown]
# ## 6. Registration

# %% [markdown]
# - Registration is performed using the VALIS program https://valis.readthedocs.io/en/stable/examples.html.
# - In the following cell, the images produced in Section 5 are combined to multi-channel tif files in a format the VALIS program is compatible with.
# - Enter the cycles being processed, the data_type desired, and the pixel size.
# - The metadata and parameters for pyramidal output may be changed.
# - Be sure the path to the vips binaries is defined correctly.

# %% [markdown]
# ### 6.1 Combine channels for each cycle

# %%
reg_start_cycle = 1
reg_end_cycle = 13
data_type = "uint16"  
pixel_size = float(0.377)

logging.basicConfig(level=logging.WARN) #change to INFO for more details

if os_system == "Windows":
    vipshome = os.path.join(base_dir, 'KINTSUGI','vips-dev-8.16','bin')
    os.environ['PATH'] = vipshome + ';' + os.environ['PATH']

import pyvips 

edf_dir = stitch_dir.replace('_BaSiC_Stitched', '_EDF')
reg_dir = edf_dir.replace('_EDF', '_Registration')
os.makedirs(reg_dir, exist_ok=True)

pbar_filesave = tqdm(total=100, unit="Percent",
                    bar_format='{l_bar}{bar}| {n_fmt}/{total_fmt} [{elapsed}<{remaining}]',
                    colour="green", position=0, leave=True)

for j in range(reg_start_cycle, reg_end_cycle + 1):

    cycle= f"cyc{str(j).zfill(2)}" 
     
    reg_source = os.path.join(edf_dir, f"cyc{str(j).zfill(2)}") 
    image_set = glob(os.path.join(reg_source, '*.tif'))
    channel_name_order = channel_name_dict.get(f"cyc{str(j).zfill(2)}.tif")
    image_set.sort(key=lambda x: channel_name_order.index(os.path.basename(x).split('.')[0]))
  
    channel_names = []
    for i in range(len(image_set)):
        split_name = os.path.basename(image_set[i].split(".")[0])
        channel_names.append(split_name)
 
    pyvips_image_set = [pyvips.Image.new_from_file(os.path.join(reg_source, filename), access="sequential") for filename in image_set]

    out_init = pyvips.Image.arrayjoin(pyvips_image_set, across=1)
    out = out_init.copy()
    out.set_type(pyvips.GValue.gint_type, "page-height", pyvips_image_set[0].height)

    x_dim = pyvips_image_set[0].width
    y_dim = pyvips_image_set[0].height

    bands = len(pyvips_image_set)
    outfile = os.path.join(reg_dir, f'cyc{str(j).zfill(2)}.ome.tif')
    out.set_type(pyvips.GValue.gstr_type, "image-description",
    f"""<?xml version="1.0" encoding="UTF-8"?>
        <OME xmlns="http://www.openmicroscopy.org/Schemas/OME/2016-06"
            xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"
            xsi:schemaLocation="http://www.openmicroscopy.org/Schemas/OME/2016-06 http://www.openmicroscopy.org/Schemas/OME/2016-06/ome.xsd">
            <Image ID="Image:0" Name="{cycle}" >
                <!-- Minimum required fields about image dimensions -->
                <Pixels BigEndian="false"
                        DimensionOrder="XYCZT" 
                        ID="Pixels:0"
                        Interleaved="false"
                        SignificantBits="16"                                              
                        SizeC="{bands}" 
                        SizeT="1" 
                        SizeX="{x_dim}" 
                        SizeY="{y_dim}" 
                        SizeZ="1" 
                        Type="{data_type}" 
                        PhysicalSizeX="{pixel_size}" 
                        PhysicalSizeY="{pixel_size}">
                    <TiffData FirstC="0" FirstT="0" FirstZ="0" IFD="0" PlaneCount="1"/>
                    <Channel Color="16751615" ID="Channel:0:0" Name="{channel_names[0]}" IlluminationType="Epifluorescence" ContrastMethod="Fluorescence" AcquisitionMode="WideField" SamplesPerPixel="1"/>
                    <TiffData FirstC="1" FirstT="0" FirstZ="0" IFD="1" PlaneCount="1"/>
                    <Channel Color="7995391" ID="Channel:0:1" Name="{channel_names[1]}" IlluminationType="Epifluorescence" ContrastMethod="Fluorescence" AcquisitionMode="WideField" SamplesPerPixel="1"/>
                    <TiffData FirstC="2" FirstT="0" FirstZ="0" IFD="2" PlaneCount="1"/>
                    <Channel Color="9043967" ID="Channel:0:2" Name="{channel_names[2]}" IlluminationType="Epifluorescence" ContrastMethod="Fluorescence" AcquisitionMode="WideField" SamplesPerPixel="1"/>
                    <TiffData FirstC="3" FirstT="0" FirstZ="0" IFD="3" PlaneCount="1"/>
                    <Channel Color="1828651263" ID="Channel:0:3" Name="{channel_names[3]}" IlluminationType="Epifluorescence" ContrastMethod="Fluorescence" AcquisitionMode="WideField" SamplesPerPixel="1"/>
                </Pixels>
            </Image>
        </OME>""")

    out.tiffsave(outfile, subifd=True, page_height=y_dim, compression='lzw', tile=True,
                  tile_width=512, tile_height=512, pyramid=True, bigtiff=True)
    out_init = None
    out = None
    pyvips_image_set = None
    gc.collect() 
    pbar_filesave.update(100 / (reg_end_cycle - reg_start_cycle + 1))

pbar_filesave.close()
# Out:
#   0%|          | 0/100 [00:00<?]

# %% [markdown]
# ### 6.2 VALIS Registration

# %% [markdown]
# - According to the VALIS docs: One of the most important parameters used to initialize a Valis object is max_processed_image_dim_px, which determines the size of the image used to find the rigid registration parameters. The default value is 850, but if registration fails or is poor, try adjusting that value. Generally speaking, values between 500-2000 work well. In cases where there is little empty space around the tissue, smaller values may be better. However, if there is a large amount of empty space/slide (as in the images above), larger values may be needed so that the tissue is at a high enough resolution. To improve alignment of the finer details in the images, larger images can be used in the non-rigid or micro-registration steps (set via the max_non_rigid_registration_dim_px parameter).
# - If you get an error that the jvm is not found, try uncommenting the registration.init_jvm() line.

# %%
os_system = platform.system()
if os_system == "Windows":
    vipshome = os.path.join(base_dir, 'KINTSUGI','vips-dev-8.16','bin')
    os.environ['PATH'] = vipshome + os.pathsep + os.environ['PATH']

mavenhome = os.path.join(base_dir, 'KINTSUGI','apache-maven-3.9.9-bin','apache-maven-3.9.9', 'bin')
os.environ['PATH'] = mavenhome + os.pathsep + os.environ['PATH']

from valis import registration
warnings.filterwarnings("ignore")

# registration.init_jvm()

edf_dir = stitch_dir.replace('_BaSiC_Stitched', '_EDF')
reg_dir = edf_dir.replace('_EDF', '_Registration')

slide_src_dir = reg_dir
results_dst_dir = os.path.join(reg_dir, "valis_out")
merged_slide_dst_f = reg_dir + "/merged.ome.tif"

# %% [markdown]
# Running this cell will produce registration data, but will not register the images, allowing for testing different parameters.

# %%
max_processed_image_dim_px = 600
registrar = registration.Valis(slide_src_dir, results_dst_dir, crop="overlap", max_processed_image_dim_px = max_processed_image_dim_px, imgs_ordered=True)
rigid_registrar, non_rigid_registrar, error_df = registrar.register()

# %% [markdown]
# - Review the results in the produced registration folder saved in “valis_out”
# - A quick method is to scroll through the “deformation_fields” images below.  Be cautious of angular deformations.

# %%
im_raw_deform = glob(os.path.join(reg_dir, "valis_out", os.path.basename(reg_dir), "deformation_fields", "*.png"))
im_deform = imread_collection(im_raw_deform)
deform = np.asarray(im_deform).astype(np.uint8)
stackview.slice(deform, continuous_update=True)

# %% [markdown]
# If further refining of results is warranted, the optional micro-registration may be run.

# %%
max_non_rigid_registration_dim_px = 2500
registrar.register_micro(max_non_rigid_registration_dim_px=max_non_rigid_registration_dim_px)

# %% [markdown]
# Here is where final registration occurs.  The first cell merges all images to one file, while the second creates one image per cycle.
# - Naming is based on the definitions of “channel_name_dict” defined above.  It may be necessary to run that cell again or copy it here.
# - The registration of the common first channel will effectively align the rest of the channels in each cycle to one another.
# - Note that writting large image files generally takes a long time.

# %%
path_to_registrar = os.path.join(reg_dir, "valis_out", os.path.basename(reg_dir),"data", os.path.basename(reg_dir)+"_registrar.pickle")
registrar = registration.load_registrar(path_to_registrar)
merged_img, channel_names, ome_xml = registrar.warp_and_merge_slides(merged_slide_dst_f,
                                    crop=True,
                                    drop_duplicates=True,
                                    channel_name_dict=channel_name_dict,                                  
                                    tile_wh=1024,
                                    Q=90,
                                    pyramid=False
)
registration.kill_jvm()

# %%
path_to_registrar = os.path.join(reg_dir, "valis_out", os.path.basename(reg_dir),"data", os.path.basename(reg_dir)+"_registrar.pickle")
registrar = registration.load_registrar(path_to_registrar)

for slide_name, slide_obj in registrar.slide_dict.items():
    reg_dir_out = os.path.join(reg_dir, "registered")
    os.makedirs(reg_dir_out, exist_ok=True)
    dst_f = os.path.join(reg_dir_out, f"{slide_name}.ome.tiff")
    slide_obj.warp_and_save_slide(dst_f=dst_f, crop="overlap", pyramid=False, interp_method = "bilinear", tile_wh=1024, Q=90)

registration.kill_jvm()
